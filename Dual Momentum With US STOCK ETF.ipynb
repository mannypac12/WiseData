# %%
import strategy as s
import matplotlib.pyplot as plt
import matplotlib as mpl


# %matplotlib inline

# %%
objOne = s.BasicDualMomentum(file="US_ETF_AND_SORTS.xlsx") 
# test_one = objOne.brc_chan_breakout()
test_two = objOne.compositReturn(windows=150, holding_date=20, start=0, sec=10)
test_two_1 = objOne.compositReturn(windows=150, holding_date=20, start=0, sec=9)
test_two_2 = objOne.compositReturn(windows=150, holding_date=20, start=0, sec=5)

# %%
for sec in objOne.ret.columns:
    print(sec)
# Out:
# iShares U.S. Basic Materials ETF
# iShares U.S. Broker-Dealers & Securities Exchanges ETF
# iShares U.S. Consumer Goods ETF
# iShares U.S. Consumer Services ETF
# iShares U.S. Energy ETF
# iShares U.S. Financials ETF
# iShares U.S. Healthcare ETF
# iShares U.S. Healthcare Providers ETF
# iShares U.S. Insurance ETF
# iShares U.S. Medical Devices ETF
# iShares U.S. Oil Equipment & Services ETF
# iShares U.S. Pharmaceuticals ETF
# iShares U.S. Regional Banks ETF
# iShares U.S. Technology ETF
# iShares U.S. Utilities ETF
# iShares US Financial Services ETF
# iShares 10-20 Year Treasury Bond ETF
# iShares 1-3 Year Treasury Bond ETF
# Invesco CurrencyShares Euro Trust

# %%
font = {'family' : 'KopubDotum',
        'size'   : 22}

mpl.rc('font', **font)
plt.rcParams['axes.unicode_minus'] = False

fig, (ax1, ax2, ax3) = plt.subplots(3,1)
fig.set_size_inches((30,30))

for i, test, ax in zip([10, 9, 5], [test_two, test_two_1, test_two_2], [ax1, ax2, ax3]):

    pf=s.PfAnalysis(test)
    (pf.cumReturn().sub(1).div(1/100)).plot(ax=ax)

    
#     ax.set_title(f"30 days Return, then holding 90 days, and the num of Max Sector is {i}")
# Out:
# C:\Users\DELL\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1328: UserWarning: findfont: Font family ['KopubDotum'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
selct_seq = objOne.DualSecurity(90)

# %%
selct_seq
# Out:
#             iShares U.S. Basic Materials ETF  \
# D A T E
# 2008-05-20                               2.0
# 2008-05-21                               2.0
# 2008-05-22                               2.0
# 2008-05-23                               2.0
# 2008-05-27                               2.0
# 2008-05-28                               2.0
# 2008-05-29                               2.0
# 2008-05-30                               2.0
# 2008-06-02                               2.0
# 2008-06-03                               2.0
# 2008-06-04                               2.0
# 2008-06-05                               2.0
# 2008-06-09                               2.0
# 2008-06-10                               2.0
# 2008-06-11                               3.0
# 2008-06-12                               2.0
# 2008-06-13                               2.0
# 2008-06-16                               3.0
# 2008-06-17                               3.0
# 2008-06-18                               3.0
# ...

# %%
select_seq_open = objOne.SelectableSecurity()

# %%
from pandas import to_datetime

select_seq_open[to_datetime('2008-03-17')]
# Out:
# ['Invesco CurrencyShares Euro Trust',
#  'iShares U.S. Energy ETF',
#  'iShares U.S. Oil Equipment & Services ETF',
#  'iShares 10-20 Year Treasury Bond ETF',
#  'iShares 1-3 Year Treasury Bond ETF',
#  'iShares U.S. Basic Materials ETF']

# %%
for i, test, ax in zip([10, 9, 5], [test_two, test_two_1, test_two_2], [ax1, ax2, ax3]):

    pf=s.PfAnalysis(test)
    print(f"{i} security's for Maximum Drawdown is {round(abs(pf.maxDrawDown())*100,2)}%")
# Out:
# 10 security's for Maximum Drawdown is 13.24%
# 9 security's for Maximum Drawdown is 13.61%
# 5 security's for Maximum Drawdown is 14.68%
