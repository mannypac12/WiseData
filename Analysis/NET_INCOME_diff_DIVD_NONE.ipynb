# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl 
from FileOpener.CSVReader.CSVReader import CSVReader as csv

# %matplotlib inline

# %% [markdown]
# # 성과분석
#
# ## 기간: 2001-04-01 ~ 2018-12-31
# ## 유니버스: 코스피 내 적자 종목 중 무배당 종목

# %%
directory = 'CSVFile/FinancialData/Korea'

net_income = csv.financial_reader('NET_INCOME_KSE.csv', directory).loc[:'2017-12-31']
divd = csv.financial_reader('DIV_OR_NOT_KSE.csv', directory).loc[:'2017-12-31']

# %%
kospi_pr = csv.price_reader('KOSPI_FROM_1998_close.csv','CSVFile/Price/Korea/Stocks' )

# %%
## Net Income Change => 년
net_income_A = net_income.resample('A-MAR').sum().loc['2001-03-31':]
net_income_A[net_income_A == 0] = np.nan

# %%
net_income_def = net_income_A < 0

# %%
net_income_def.head()
# Out:
#             A000010  A000020  A000030  A000040  A000050  A000060  A000070  \
# Code
# 2001-03-31     True    False     True     True     True    False    False
# 2002-03-31    False    False    False    False    False    False     True
# 2003-03-31     True    False    False     True    False    False    False
# 2004-03-31     True    False    False    False     True    False    False
# 2005-03-31    False    False    False     True     True    False    False
#
#             A000080  A000090  A000100   ...     A298050  A298690  A300720  \
# Code                                    ...
# 2001-03-31     True    False    False   ...       False    False    False
# 2002-03-31     True    False    False   ...       False    False    False
# 2003-03-31    False    False    False   ...       False    False    False
# 2004-03-31     True    False    False   ...       False    False    False
# 2005-03-31     True    False    False   ...       False    False    False
#
#             A306200  A900030  A900050  A900140  A950010  A950070  A950100
# Code
# 2001-03-31    False    False    False    False    False    False    False
# 2002-03-31    False    False    False    False    False    False    False
# 2003-03-31    False    False    False    False    False    False    False
# 2004-03-31    False    False    False    False    False    False    False
# 2005-03-31    False    False    False    False    False    False    False
#
# [5 rows x 1192 columns]

# %% [markdown]
# ### Dividend Index 정재

# %%
divd.index = net_income_A.index

# %%
divd_none = divd.isnull()

# %%
divd_none.head()
# Out:
#             A000010  A000020  A000030  A000040  A000050  A000060  A000070  \
# Code
# 2001-03-31     True    False     True     True    False    False    False
# 2002-03-31     True    False    False     True    False    False    False
# 2003-03-31     True    False    False     True    False    False    False
# 2004-03-31     True    False    False     True    False    False    False
# 2005-03-31     True    False     True     True     True    False    False
#
#             A000080  A000090  A000100   ...     A298050  A298690  A300720  \
# Code                                    ...
# 2001-03-31     True     True    False   ...        True     True     True
# 2002-03-31     True     True    False   ...        True     True     True
# 2003-03-31     True     True    False   ...        True     True     True
# 2004-03-31     True     True    False   ...        True     True     True
# 2005-03-31     True     True    False   ...        True     True     True
#
#             A306200  A900030  A900050  A900140  A950010  A950070  A950100
# Code
# 2001-03-31     True     True     True     True     True     True     True
# 2002-03-31     True     True     True     True     True     True     True
# 2003-03-31     True     True     True     True     True     True     True
# 2004-03-31     True     True     True     True     True     True     True
# 2005-03-31     True     True     True     True     True     True     True
#
# [5 rows x 1192 columns]

# %%
divd_none_net_def = net_income_def & divd_none
divd_none_net_def.head()
# Out:
#             A000010  A000020  A000030  A000040  A000050  A000060  A000070  \
# Code
# 2001-03-31     True    False     True     True    False    False    False
# 2002-03-31    False    False    False    False    False    False    False
# 2003-03-31     True    False    False     True    False    False    False
# 2004-03-31     True    False    False    False    False    False    False
# 2005-03-31    False    False    False     True     True    False    False
#
#             A000080  A000090  A000100   ...     A298050  A298690  A300720  \
# Code                                    ...
# 2001-03-31     True    False    False   ...       False    False    False
# 2002-03-31     True    False    False   ...       False    False    False
# 2003-03-31    False    False    False   ...       False    False    False
# 2004-03-31     True    False    False   ...       False    False    False
# 2005-03-31     True    False    False   ...       False    False    False
#
#             A306200  A900030  A900050  A900140  A950010  A950070  A950100
# Code
# 2001-03-31    False    False    False    False    False    False    False
# 2002-03-31    False    False    False    False    False    False    False
# 2003-03-31    False    False    False    False    False    False    False
# 2004-03-31    False    False    False    False    False    False    False
# 2005-03-31    False    False    False    False    False    False    False
#
# [5 rows x 1192 columns]

# %% [markdown]
# ## 동일가중 1년간 리밸런싱

# %%
from FileOpener.backtester import FinancialBacktest

# %%
KOSPI = FinancialBacktest(kospi_pr)

# %%
KOSPI.back_date(divd_none_net_def, 'A-MAR')
# Out:
# (DatetimeIndex(['2001-03-31', '2002-03-31', '2003-03-31', '2004-03-31',
#                 '2005-03-31', '2006-03-31', '2007-03-31', '2008-03-31',
#                 '2009-03-31', '2010-03-31', '2011-03-31', '2012-03-31',
#                 '2013-03-31', '2014-03-31', '2015-03-31', '2016-03-31',
#                 '2017-03-31', '2018-03-31'],
#                dtype='datetime64[ns]', freq='A-MAR'),
#  DatetimeIndex(['2001-04-01', '2002-04-01', '2003-04-01', '2004-04-01',
#                 '2005-04-01', '2006-04-01', '2007-04-01', '2008-04-01',
#                 '2009-04-01', '2010-04-01', '2011-04-01', '2012-04-01',
#                 '2013-04-01', '2014-04-01', '2015-04-01', '2016-04-01',
#                 '2017-04-01'],
#                dtype='datetime64[ns]', freq='AS-APR'),
#  DatetimeIndex(['2002-03-31', '2003-03-31', '2004-03-31', '2005-03-31',
#                 '2006-03-31', '2007-03-31', '2008-03-31', '2009-03-31',
#                 '2010-03-31', '2011-03-31', '2012-03-31', '2013-03-31',
#                 '2014-03-31', '2015-03-31', '2016-03-31', '2017-03-31',
#                 '2018-03-31'],
#                dtype='datetime64[ns]', freq='A-MAR'))

# %%
KOSPI.stock_screen(divd_none_net_def, 'A-MAR')
# Out:
# {Timestamp('2001-03-31 00:00:00', freq='A-MAR'): Index(['A000010', 'A000030', 'A000040', 'A000080', 'A000180', 'A000200',
#         'A000280', 'A000300', 'A000310', 'A000370',
#         ...
#         'A024870', 'A025620', 'A025840', 'A025890', 'A025930', 'A027390',
#         'A032640', 'A035720', 'A042670', 'A047050'],
#        dtype='object', length=235),
#  Timestamp('2002-03-31 00:00:00', freq='A-MAR'): Index(['A000080', 'A000150', 'A000310', 'A000660', 'A000720', 'A000760',
#         'A000790', 'A000880', 'A000890', 'A001030',
#         ...
#         'A024870', 'A024890', 'A025560', 'A025830', 'A025840', 'A031820',
#         'A034830', 'A035720', 'A047050', 'A063510'],
#        dtype='object', length=192),
#  Timestamp('2003-03-31 00:00:00', freq='A-MAR'): Index(['A000010', 'A000040', 'A000150', 'A000300', 'A000370', 'A000420',
#         'A000470', 'A000540', 'A000660', 'A000720',
#         ...
#         'A030210', 'A030610', 'A031820', 'A033250', 'A038400', 'A051630',
#         'A063160', 'A063510', 'A068870', 'A069470'],
#        dtype='object', length=178),
#  Timestamp('2004-03-31 00:00:00', freq='A-MAR'): Index(['A000010', 'A000300', 'A000470', 'A000540', 'A000610', 'A000660',
#         'A000760', 'A001020', 'A001150', 'A001190',
#         ...
#         'A027740', 'A028050', 'A030720', 'A031820', 'A032710', 'A033250',
#         'A038400', 'A060000', 'A063510', 'A069470'],
#        dtype='object', length=137),
#  Timestamp('2005-03-31 00:00:00', freq='A-MAR'): Index(['A000040', 'A000050', 'A000150', 'A000300', 'A000420', 'A000760',
#         'A001190', 'A001260', 'A001270', 'A001280',
#         ...
#         'A024870', 'A025560', 'A025620', 'A026890', 'A030210', 'A030790',
#         'A031820', 'A033250', 'A035720', 'A079660'],
#        dtype='object', length=130),
#  Timestamp('2006-03-31 00:00:00', freq='A-MAR'): Index(['A000040', 'A000150', 'A000300', 'A000370', 'A000420', 'A000540',
#         'A000650', 'A000760', 'A000790', 'A001250',
#         ...
#         'A033250', 'A034830', 'A035720', 'A063160', 'A063350', 'A068870',
#         'A069470', 'A076170', 'A079660', 'A084680'],
#        dtype='object', length=110),
#  Timestamp('2007-03-31 00:00:00', freq='A-MAR'): Index(['A000040', 'A000120', 'A000270', 'A000300', 'A000370', 'A000420',
#         'A000540', 'A000680', 'A000760', 'A000790',
#         ...
#         'A034220', 'A049800', 'A063160', 'A063350', 'A069470', 'A074610',
#         'A076170', 'A078520', 'A090080', 'A092220'],
#        dtype='object', length=114),
#  Timestamp('2008-03-31 00:00:00', freq='A-MAR'): Index(['A000050', 'A000180', 'A000420', 'A000540', 'A000660', 'A000990',
#         'A001070', 'A001190', 'A001360', 'A001380',
#         ...
#         'A030720', 'A035150', 'A049800', 'A063160', 'A069470', 'A074610',
#         'A076170', 'A078520', 'A090080', 'A096760'],
#        dtype='object', length=103),
#  Timestamp('2009-03-31 00:00:00', freq='A-MAR'): Index(['A000040', 'A000050', 'A000060', 'A000180', 'A000400', 'A000420',
#         'A000470', 'A000540', 'A000660', 'A000760',
#         ...
#         'A094280', 'A096760', 'A101140', 'A101990', 'A102260', 'A102280',
#         'A103140', 'A103590', 'A109070', 'A900030'],
#        dtype='object', length=181),
#  Timestamp('2010-03-31 00:00:00', freq='A-MAR'): Index(['A000040', 'A000120', 'A000370', 'A000470', 'A000540', 'A000700',
#         'A000990', 'A001020', 'A001070', 'A001260',
#         ...
#         'A073240', 'A074610', 'A081000', 'A084680', 'A092220', 'A101990',
#         'A102280', 'A104110', 'A117930', 'A900030'],
#        dtype='object', length=106),
#  Timestamp('2011-03-31 00:00:00', freq='A-MAR'): Index(['A000180', 'A000400', 'A000470', 'A000540', 'A000890', 'A000990',
#         'A001200', 'A001260', 'A001310', 'A001360',
#         ...
#         'A084680', 'A092220', 'A094280', 'A101140', 'A101990', 'A109070',
#         'A118000', 'A123690', 'A128940', 'A950070'],
#        dtype='object', length=103),
#  Timestamp('2012-03-31 00:00:00', freq='A-MAR'): Index(['A000050', 'A000360', 'A000420', 'A000470', 'A000660', 'A000700',
#         'A000760', 'A000890', 'A000950', 'A000990',
#         ...
#         'A101990', 'A103130', 'A104120', 'A109070', 'A117930', 'A118000',
#         'A128820', 'A128940', 'A900030', 'A950070'],
#        dtype='object', length=143),
#  Timestamp('2013-03-31 00:00:00', freq='A-MAR'): Index(['A000040', 'A000050', 'A000300', 'A000360', 'A000400', 'A000420',
#         'A000800', 'A000890', 'A000950', 'A000990',
#         ...
#         'A103130', 'A104110', 'A104120', 'A109070', 'A110570', 'A117930',
#         'A118000', 'A123690', 'A128820', 'A950070'],
#        dtype='object', length=147),
#  Timestamp('2014-03-31 00:00:00', freq='A-MAR'): Index(['A000040', 'A000120', 'A000180', 'A000360', 'A000370', 'A000400',
#         'A000420', 'A000700', 'A000760', 'A000800',
#         ...
#         'A109070', 'A110570', 'A117930', 'A118000', 'A123690', 'A128820',
#         'A134790', 'A138490', 'A950010', 'A950070'],
#        dtype='object', length=164),
#  Timestamp('2015-03-31 00:00:00', freq='A-MAR'): Index(['A000040', 'A000180', 'A000300', 'A000360', 'A000420', 'A000800',
#         'A000950', 'A001020', 'A001070', 'A001210',
#         ...
#         'A103130', 'A109070', 'A110570', 'A117930', 'A118000', 'A119650',
#         'A128820', 'A134790', 'A144620', 'A900050'],
#        dtype='object', length=150),
#  Timestamp('2016-03-31 00:00:00', freq='A-MAR'): Index(['A000040', 'A000680', 'A000760', 'A000950', 'A001020', 'A001070',
#         'A001210', 'A001250', 'A001260', 'A001290',
#         ...
#         'A110570', 'A117930', 'A118000', 'A119650', 'A123690', 'A128820',
#         'A133820', 'A134790', 'A144620', 'A900050'],
#        dtype='object', length=137),
#  Timestamp('2017-03-31 00:00:00', freq='A-MAR'): Index(['A000040', 'A000680', 'A000760', 'A000890', 'A000950', 'A001020',
#         'A001070', 'A001140', 'A001210', 'A001290',
#         ...
#         'A109070', 'A110570', 'A111110', 'A117930', 'A118000', 'A128820',
#         'A180640', 'A181710', 'A207940', 'A900050'],
#        dtype='object', length=121),
#  Timestamp('2018-03-31 00:00:00', freq='A-MAR'): Index(['A000040', 'A000300', 'A000760', 'A001020', 'A001070', 'A001140',
#         'A001290', 'A001360', 'A001380', 'A001440',
#         ...
#         'A105840', 'A109070', 'A118000', 'A123690', 'A134790', 'A144620',
#         'A145210', 'A181710', 'A207940', 'A285130'],
#        dtype='object', length=116)}

# %%
kospi_rt = KOSPI.backtest(divd_none_net_def, 'A-MAR', 'A-MAR')

# %%
from FileOpener.backtester import PfAnalysis

# %%
KOSPI_pf = PfAnalysis(kospi_rt)

# %%
import matplotlib as mpl

# %%
mpl.rcParams['font.sans-serif'] = ['KoPubDotum']
mpl.rcParams['font.size'] = 15

# %% [markdown]
# ## 성과분석
#
# ### 당기순익 적자 / 무배당 주식

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)


KOSPI_pf.cumReturn().plot(ax=ax, lw = 2, color='red')


ax.yaxis.set_major_formatter(mpl.ticker.FuncFormatter(lambda y, _: '{:.0%}'.format(y)))
ax.margins(x=0, tight=True)
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

# %%
print(f"CAGR: {round(KOSPI_pf.cagr() * 100, 2)}%")
print(f"Total Return: {round(KOSPI_pf.totalReturn()* 100, 2)}%")
print(f"Maiximum Drawdown: {abs(round(KOSPI_pf.maxDrawDown()* 100, 2))}%")
# Out:
# CAGR: 5.61%
# Total Return: 152.76%
# Maiximum Drawdown: 64.47%
