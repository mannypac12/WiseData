# %%
import pandas as pd
from pandas.tseries.offsets import MonthEnd
import numpy as np
import matplotlib 


# %matplotlib inline

# %% [markdown]
# # Bring the file
#
# ## Price Data
#
# ### 코스피
# -- 00.07.01 ~ 19.01.14
# ### 당기순익(분기)
# -- 00.1Q ~ 18.3Q

# %%
directory = 'CSVFile/FinancialData/Korea'

def financialReader(filename, directory):
    
    a = pd.read_csv(f"{directory}/NET_INCOME_KSE.csv", skiprows = 1)
    a['Code'] = pd.to_datetime(a['Code'].astype('str'), format='%Y%m') + MonthEnd()
    return a.set_index('Code')

# %% [markdown]
# ## Net Income

# %%
## Cleansing AR
## Date => 'YYYY-MM-DD'

net_income = financialReader('NET_INCOME_KSE.csv', directory).shift(1).dropna(axis = 0, how = 'all')

# %%
def plus_to_nan(x):
    
    if x < 0: 
        return False
    elif x >= 0: 
        return True
    else:
        return np.nan

net_income_plus = net_income.applymap(plus_to_nan)

# %%
net_income_plus.head()
# Out:
#             A000010 A000020  A000030  A000040  A000050 A000060 A000070  \
# Code
# 2000-06-30     True     NaN     True    False     True     NaN     NaN
# 2000-09-30    False    True    False    False    False     NaN     NaN
# 2000-12-31     True    True    False    False     True     NaN    True
# 2001-03-31    False    True    False    False    False   False    True
# 2001-06-30     True    True     True     True     True    True    True
#
#            A000080  A000090  A000100   ...     A298050  A298690  A300720  \
# Code                                   ...
# 2000-06-30     NaN      NaN     True   ...         NaN      NaN      NaN
# 2000-09-30     NaN      NaN     True   ...         NaN      NaN      NaN
# 2000-12-31     NaN      NaN     True   ...         NaN      NaN      NaN
# 2001-03-31   False      NaN     True   ...         NaN      NaN      NaN
# 2001-06-30   False      NaN     True   ...         NaN      NaN      NaN
#
#             A306200  A900030  A900050  A900140 A950010 A950070  A950100
# Code
# 2000-06-30      NaN      NaN      NaN      NaN     NaN     NaN      NaN
# 2000-09-30      NaN      NaN      NaN      NaN     NaN     NaN      NaN
# 2000-12-31      NaN      NaN      NaN      NaN     NaN     NaN      NaN
# 2001-03-31      NaN      NaN      NaN      NaN     NaN     NaN      NaN
# 2001-06-30      NaN      NaN      NaN      NaN     NaN     NaN      NaN
#
# [5 rows x 1192 columns]

# %% [markdown]
# ## KOSPI FROM '2000-07-01'

# %%
## 적자기업 1년 투자
pr_directory = 'CSVFile/Price/Korea/Stocks'
price = pd.read_csv(f"{pr_directory}/KOSPI_FROM_1998_close.csv", index_col = 'D A T E', parse_dates=True).loc['2000-07-01':]
price.head()
# Out:
#             A000010  A000020  A000030  A000040  A000050  A000060  A000070  \
# D A T E
# 2000-07-03   3665.0     1891   2730.0     7417     1644      469    11773
# 2000-07-04   3250.0     1922   2395.0     7342     1629      505    12151
# 2000-07-05   3735.0     1866   2750.0     7342     1619      495    11503
# 2000-07-06   3940.0     1836   2735.0     7642     1647      534    11341
# 2000-07-07   3895.0     1885   2730.0     7717     1644      546    11557
#
#             A000080  A000090  A000100   ...     A298050  A298690  A300720  \
# D A T E                                 ...
# 2000-07-03   3290.0      NaN    17745   ...         NaN      NaN      NaN
# 2000-07-04   3280.0      NaN    17996   ...         NaN      NaN      NaN
# 2000-07-05   3190.0      NaN    17996   ...         NaN      NaN      NaN
# 2000-07-06   3110.0      NaN    18800   ...         NaN      NaN      NaN
# 2000-07-07   3120.0      NaN    19102   ...         NaN      NaN      NaN
#
#             A306200  A900030  A900050  A900140  A950010  A950070  A950100
# D A T E
# 2000-07-03      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2000-07-04      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2000-07-05      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2000-07-06      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2000-07-07      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
# [5 rows x 1192 columns]

# %% [markdown]
# ## 수익률 계산시 극단값 조정

# %%
price_rt = price.pct_change().dropna(axis = 0, how = 'all')

# %%
((price_rt > 0.3).sum()).sum()
# Out:
# 367

# %%
price_rt[price_rt > 0.3] = 0.3

# %% [markdown]
# ## 주식 유니버스 선정

# %%
## Universe
none_invest = net_income_plus.isnull()
plus_invest = net_income_plus == True
minus_invest = (net_income_plus == False) & ~none_invest

# %%
plus_invest
# Out:
#             A000010  A000020  A000030  A000040  A000050  A000060  A000070  \
# Code
# 2000-06-30     True    False     True    False     True    False    False
# 2000-09-30    False     True    False    False    False    False    False
# 2000-12-31     True     True    False    False     True    False     True
# 2001-03-31    False     True    False    False    False    False     True
# 2001-06-30     True     True     True     True     True     True     True
# 2001-09-30     True     True     True    False    False     True    False
# 2001-12-31     True     True     True    False     True     True     True
# 2002-03-31     True     True     True    False    False     True     True
# 2002-06-30     True     True     True     True     True     True     True
# 2002-09-30     True     True     True     True     True     True     True
# 2002-12-31    False     True     True    False     True     True     True
# 2003-03-31    False     True    False    False    False     True     True
# 2003-06-30     True     True     True    False     True     True     True
# 2003-09-30    False     True     True    False     True     True     True
# 2003-12-31    False     True     True    False    False    False     True
# 2004-03-31    False     True     True     True    False     True     True
# 2004-06-30     True     True     True    False     True     True     True
# 2004-09-30     True     True     True    False    False     True     True
# 2004-12-31     True     True     True    False    False     True     True
# 2005-03-31     True     True     True    False    False     True    False
# 2005-06-30     True     True     True    False     True     True     True
# 2005-09-30     True     True     True     True     True     True     True
# 2005-12-31     True     True     True    False    False     True     True
# 2006-03-31     True     True     True     True    False    False     True
# 2006-06-30     True     True     True    False     True     True     True
# 2006-09-30     True     True     True    False    False     True     True
# 2006-12-31     True     True     True    False    False     True     True
# 2007-03-31     True     True     True    False    False     True    False
# 2007-06-30     True     True     True    False     True     True     True
# 2007-09-30     True     True     True    False    False     True     True
# ...             ...      ...      ...      ...      ...      ...      ...
# 2011-06-30     True     True     True     True     True     True     True
# 2011-09-30     True     True     True     True     True     True     True
# 2011-12-31     True     True     True     True    False     True     True
# 2012-03-31     True     True     True    False    False     True     True
# 2012-06-30     True     True     True    False    False     True     True
# 2012-09-30     True     True     True    False    False     True     True
# 2012-12-31     True     True     True    False    False     True     True
# 2013-03-31     True    False     True    False     True     True    False
# 2013-06-30     True     True     True    False     True     True     True
# 2013-09-30     True     True     True     True     True     True    False
# 2013-12-31     True    False     True    False     True     True     True
# 2014-03-31     True    False    False    False     True     True    False
# 2014-06-30     True     True     True    False     True     True     True
# 2014-09-30     True     True     True    False     True     True     True
# 2014-12-31     True     True     True    False     True     True     True
# 2015-03-31     True     True     True    False     True     True    False
# 2015-06-30     True     True     True    False     True     True     True
# 2015-09-30     True     True     True    False     True     True     True
# 2015-12-31     True    False     True    False     True     True     True
# 2016-03-31     True     True     True    False     True     True     True
# 2016-06-30     True     True     True    False     True     True     True
# 2016-09-30     True     True     True     True     True     True     True
# 2016-12-31     True     True     True    False     True     True     True
# 2017-03-31     True     True     True    False     True     True    False
# 2017-06-30     True     True     True    False     True     True     True
# 2017-09-30     True     True     True    False     True     True     True
# 2017-12-31     True     True     True    False     True     True     True
# 2018-03-31     True     True     True    False     True     True    False
# 2018-06-30     True     True     True    False     True     True     True
# 2018-09-30     True     True     True    False     True     True     True
#
#             A000080  A000090  A000100   ...     A298050  A298690  A300720  \
# Code                                    ...
# 2000-06-30    False    False     True   ...       False    False    False
# 2000-09-30    False    False     True   ...       False    False    False
# 2000-12-31    False    False     True   ...       False    False    False
# 2001-03-31    False    False     True   ...       False    False    False
# 2001-06-30    False    False     True   ...       False    False    False
# 2001-09-30    False    False     True   ...       False    False    False
# 2001-12-31    False    False     True   ...       False    False    False
# 2002-03-31    False    False     True   ...       False    False    False
# 2002-06-30    False    False     True   ...       False    False    False
# 2002-09-30    False    False     True   ...       False    False    False
# 2002-12-31    False    False     True   ...       False    False    False
# 2003-03-31     True    False     True   ...       False    False    False
# 2003-06-30    False    False     True   ...       False    False    False
# 2003-09-30    False    False     True   ...       False    False    False
# 2003-12-31    False    False     True   ...       False    False    False
# 2004-03-31     True    False     True   ...       False    False    False
# 2004-06-30    False    False     True   ...       False    False    False
# 2004-09-30     True    False     True   ...       False    False    False
# 2004-12-31    False    False     True   ...       False    False    False
# 2005-03-31     True    False     True   ...       False    False    False
# 2005-06-30     True    False     True   ...       False    False    False
# 2005-09-30     True    False     True   ...       False    False    False
# 2005-12-31     True    False     True   ...       False    False    False
# 2006-03-31     True    False     True   ...       False    False    False
# 2006-06-30     True    False     True   ...       False    False    False
# 2006-09-30     True    False     True   ...       False    False    False
# 2006-12-31     True    False     True   ...       False    False    False
# 2007-03-31    False    False     True   ...       False    False    False
# 2007-06-30     True    False     True   ...       False    False    False
# 2007-09-30     True    False     True   ...       False    False    False
# ...             ...      ...      ...   ...         ...      ...      ...
# 2011-06-30     True    False     True   ...       False    False    False
# 2011-09-30     True    False     True   ...       False    False    False
# 2011-12-31     True    False     True   ...       False    False    False
# 2012-03-31    False    False     True   ...       False    False    False
# 2012-06-30     True    False     True   ...       False    False    False
# 2012-09-30     True    False     True   ...       False    False    False
# 2012-12-31     True    False     True   ...       False    False    False
# 2013-03-31     True    False     True   ...       False    False    False
# 2013-06-30     True    False     True   ...       False    False    False
# 2013-09-30     True    False     True   ...       False    False    False
# 2013-12-31     True    False     True   ...       False    False    False
# 2014-03-31     True    False     True   ...       False    False    False
# 2014-06-30    False    False     True   ...       False    False    False
# 2014-09-30     True    False     True   ...       False    False    False
# 2014-12-31     True    False     True   ...       False    False    False
# 2015-03-31    False    False     True   ...       False    False    False
# 2015-06-30     True    False     True   ...       False    False    False
# 2015-09-30     True    False     True   ...       False    False    False
# 2015-12-31     True    False     True   ...       False    False    False
# 2016-03-31     True    False     True   ...       False    False    False
# 2016-06-30     True    False     True   ...       False    False    False
# 2016-09-30     True    False     True   ...       False    False    False
# 2016-12-31     True    False     True   ...       False    False    False
# 2017-03-31     True    False     True   ...       False    False    False
# 2017-06-30    False    False     True   ...       False    False    False
# 2017-09-30     True    False     True   ...       False    False    False
# 2017-12-31     True    False     True   ...       False    False    False
# 2018-03-31    False    False     True   ...       False    False    False
# 2018-06-30     True    False     True   ...       False    False    False
# 2018-09-30     True    False     True   ...        True    False    False
#
#             A306200  A900030  A900050  A900140  A950010  A950070  A950100
# Code
# 2000-06-30    False    False    False    False    False    False    False
# 2000-09-30    False    False    False    False    False    False    False
# 2000-12-31    False    False    False    False    False    False    False
# 2001-03-31    False    False    False    False    False    False    False
# 2001-06-30    False    False    False    False    False    False    False
# 2001-09-30    False    False    False    False    False    False    False
# 2001-12-31    False    False    False    False    False    False    False
# 2002-03-31    False    False    False    False    False    False    False
# 2002-06-30    False    False    False    False    False    False    False
# 2002-09-30    False    False    False    False    False    False    False
# 2002-12-31    False    False    False    False    False    False    False
# 2003-03-31    False    False    False    False    False    False    False
# 2003-06-30    False    False    False    False    False    False    False
# 2003-09-30    False    False    False    False    False    False    False
# 2003-12-31    False    False    False    False    False    False    False
# 2004-03-31    False    False    False    False    False    False    False
# 2004-06-30    False    False    False    False    False    False    False
# 2004-09-30    False    False    False    False    False    False    False
# 2004-12-31    False    False    False    False    False    False    False
# 2005-03-31    False    False    False    False    False    False    False
# 2005-06-30    False    False    False    False    False    False    False
# 2005-09-30    False    False    False    False    False    False    False
# 2005-12-31    False    False    False    False    False    False    False
# 2006-03-31    False    False    False    False    False    False    False
# 2006-06-30    False    False    False    False    False    False    False
# 2006-09-30    False    False    False    False    False    False    False
# 2006-12-31    False    False    False    False    False    False    False
# 2007-03-31    False    False    False    False    False    False    False
# 2007-06-30    False    False    False    False    False    False    False
# 2007-09-30    False    False    False    False    False    False    False
# ...             ...      ...      ...      ...      ...      ...      ...
# 2011-06-30    False     True     True     True    False    False    False
# 2011-09-30    False     True     True     True    False    False    False
# 2011-12-31    False    False     True     True    False    False    False
# 2012-03-31    False    False    False     True    False    False     True
# 2012-06-30    False     True     True     True    False    False     True
# 2012-09-30    False    False     True     True    False    False     True
# 2012-12-31    False    False    False     True    False    False     True
# 2013-03-31    False    False     True     True    False    False     True
# 2013-06-30    False    False     True     True    False    False     True
# 2013-09-30    False    False     True     True    False    False     True
# 2013-12-31    False    False     True     True    False    False     True
# 2014-03-31    False    False     True     True    False    False     True
# 2014-06-30    False    False    False     True    False    False     True
# 2014-09-30    False    False    False     True    False    False     True
# 2014-12-31    False    False    False     True    False    False     True
# 2015-03-31    False    False    False     True    False    False    False
# 2015-06-30    False    False    False     True    False    False    False
# 2015-09-30    False    False     True     True    False    False    False
# 2015-12-31    False    False    False     True    False    False    False
# 2016-03-31    False    False    False     True    False    False    False
# 2016-06-30    False    False    False     True    False    False    False
# 2016-09-30    False    False    False     True    False    False    False
# 2016-12-31    False    False    False     True    False    False    False
# 2017-03-31    False    False    False     True    False    False    False
# 2017-06-30    False    False    False     True    False    False    False
# 2017-09-30    False    False    False     True    False    False    False
# 2017-12-31    False    False    False     True    False    False    False
# 2018-03-31    False    False    False    False    False    False    False
# 2018-06-30    False    False    False     True    False    False    False
# 2018-09-30    False    False    False    False    False    False    False
#
# [74 rows x 1192 columns]

# %%
minus_data = {}
date_index = minus_invest.index

for date in date_index:

    minus_data[date] = (minus_invest.loc[date][minus_invest.loc[date] == True]).index

minus_data
# Out:
# {Timestamp('2000-06-30 00:00:00'): Index(['A000040', 'A000200', 'A000280', 'A000300', 'A000660', 'A000790',
#         'A000800', 'A000890', 'A000910', 'A000980',
#         ...
#         'A017120', 'A017550', 'A018360', 'A018410', 'A018570', 'A025620',
#         'A025840', 'A025890', 'A027390', 'A032640'],
#        dtype='object', length=130),
#  Timestamp('2000-09-30 00:00:00'): Index(['A000010', 'A000030', 'A000040', 'A000050', 'A000200', 'A000210',
#         'A000280', 'A000300', 'A000650', 'A000660',
#         ...
#         'A018570', 'A023590', 'A024870', 'A025620', 'A025890', 'A027390',
#         'A027970', 'A032640', 'A035150', 'A035510'],
#        dtype='object', length=176),
#  Timestamp('2000-12-31 00:00:00'): Index(['A000030', 'A000040', 'A000280', 'A000300', 'A000310', 'A000420',
#         'A000490', 'A000720', 'A000760', 'A000790',
#         ...
#         'A025890', 'A025930', 'A026870', 'A027390', 'A032640', 'A034020',
#         'A035150', 'A035250', 'A035720', 'A036460'],
#        dtype='object', length=227),
#  Timestamp('2001-03-31 00:00:00'): Index(['A000010', 'A000030', 'A000040', 'A000050', 'A000060', 'A000080',
#         'A000120', 'A000150', 'A000180', 'A000210',
#         ...
#         'A033250', 'A034020', 'A034830', 'A035510', 'A035720', 'A036460',
#         'A036580', 'A039130', 'A042670', 'A122900'],
#        dtype='object', length=384),
#  Timestamp('2001-06-30 00:00:00'): Index(['A000080', 'A000180', 'A000210', 'A000220', 'A000300', 'A000310',
#         'A000370', 'A000390', 'A000400', 'A000420',
#         ...
#         'A025610', 'A025620', 'A025840', 'A025890', 'A031820', 'A033250',
#         'A034220', 'A036580', 'A047050', 'A053210'],
#        dtype='object', length=240),
#  Timestamp('2001-09-30 00:00:00'): Index(['A000040', 'A000050', 'A000070', 'A000080', 'A000300', 'A000310',
#         'A000420', 'A000660', 'A000670', 'A000720',
#         ...
#         'A031820', 'A033250', 'A034020', 'A034220', 'A035720', 'A036460',
#         'A036570', 'A047040', 'A047050', 'A053210'],
#        dtype='object', length=213),
#  Timestamp('2001-12-31 00:00:00'): Index(['A000040', 'A000080', 'A000150', 'A000180', 'A000300', 'A000370',
#         'A000400', 'A000420', 'A000430', 'A000470',
#         ...
#         'A031820', 'A034220', 'A034830', 'A035720', 'A036460', 'A047040',
#         'A047050', 'A049800', 'A053210', 'A067250'],
#        dtype='object', length=278),
#  Timestamp('2002-03-31 00:00:00'): Index(['A000040', 'A000050', 'A000080', 'A000110', 'A000120', 'A000150',
#         'A000490', 'A000660', 'A000670', 'A000680',
#         ...
#         'A034220', 'A034830', 'A035150', 'A035720', 'A042670', 'A053210',
#         'A058850', 'A058860', 'A063510', 'A064420'],
#        dtype='object', length=298),
#  Timestamp('2002-06-30 00:00:00'): Index(['A000080', 'A000420', 'A000540', 'A000700', 'A000760', 'A000790',
#         'A001140', 'A001380', 'A001390', 'A001430',
#         ...
#         'A024890', 'A025560', 'A025850', 'A025860', 'A033250', 'A033270',
#         'A033660', 'A035720', 'A047050', 'A063510'],
#        dtype='object', length=125),
#  Timestamp('2002-09-30 00:00:00'): Index(['A000080', 'A000300', 'A000370', 'A000400', 'A000420', 'A000470',
#         'A000610', 'A000660', 'A000760', 'A000880',
#         ...
#         'A028050', 'A029460', 'A033240', 'A033660', 'A034020', 'A035150',
#         'A035720', 'A036460', 'A038400', 'A063510'],
#        dtype='object', length=166),
#  Timestamp('2002-12-31 00:00:00'): Index(['A000010', 'A000040', 'A000080', 'A000180', 'A000300', 'A000370',
#         'A000420', 'A000490', 'A000540', 'A000610',
#         ...
#         'A032640', 'A033250', 'A036460', 'A038400', 'A041650', 'A051630',
#         'A063510', 'A064420', 'A064960', 'A068870'],
#        dtype='object', length=202),
#  Timestamp('2003-03-31 00:00:00'): Index(['A000010', 'A000030', 'A000040', 'A000050', 'A000150', 'A000300',
#         'A000370', 'A000420', 'A000470', 'A000490',
#         ...
#         'A051900', 'A058850', 'A058860', 'A060000', 'A063160', 'A063510',
#         'A064960', 'A066570', 'A068870', 'A069470'],
#        dtype='object', length=268),
#  Timestamp('2003-06-30 00:00:00'): Index(['A000040', 'A000080', 'A000110', 'A000180', 'A000300', 'A000370',
#         'A000470', 'A000540', 'A000650', 'A000660',
#         ...
#         'A031820', 'A032710', 'A033250', 'A034220', 'A038400', 'A051630',
#         'A063510', 'A068870', 'A069460', 'A069470'],
#        dtype='object', length=189),
#  Timestamp('2003-09-30 00:00:00'): Index(['A000010', 'A000040', 'A000080', 'A000300', 'A000420', 'A000470',
#         'A000660', 'A000720', 'A001150', 'A001190',
#         ...
#         'A032710', 'A033250', 'A035150', 'A038400', 'A039130', 'A047810',
#         'A060000', 'A064420', 'A069470', 'A070960'],
#        dtype='object', length=161),
#  Timestamp('2003-12-31 00:00:00'): Index(['A000010', 'A000040', 'A000050', 'A000060', 'A000080', 'A000150',
#         'A000300', 'A000370', 'A000400', 'A000420',
#         ...
#         'A041650', 'A044820', 'A053000', 'A053210', 'A058430', 'A060000',
#         'A063510', 'A068870', 'A069470', 'A070960'],
#        dtype='object', length=215),
#  Timestamp('2004-03-31 00:00:00'): Index(['A000010', 'A000050', 'A000300', 'A000470', 'A000490', 'A000520',
#         'A000540', 'A000610', 'A000660', 'A000760',
#         ...
#         'A063160', 'A063510', 'A064420', 'A066570', 'A067250', 'A067830',
#         'A069460', 'A069470', 'A069960', 'A070960'],
#        dtype='object', length=273),
#  Timestamp('2004-06-30 00:00:00'): Index(['A000040', 'A000080', 'A000300', 'A000470', 'A000540', 'A000760',
#         'A000910', 'A001140', 'A001190', 'A001380',
#         ...
#         'A029780', 'A030610', 'A030790', 'A032640', 'A032830', 'A033250',
#         'A053000', 'A053210', 'A064350', 'A069620'],
#        dtype='object', length=139),
#  Timestamp('2004-09-30 00:00:00'): Index(['A000040', 'A000050', 'A000300', 'A000420', 'A000470', 'A000760',
#         'A000910', 'A001190', 'A001200', 'A001280',
#         ...
#         'A033250', 'A035150', 'A036460', 'A036580', 'A049800', 'A053210',
#         'A064350', 'A067250', 'A067830', 'A070960'],
#        dtype='object', length=143),
#  Timestamp('2004-12-31 00:00:00'): Index(['A000040', 'A000050', 'A000080', 'A000150', 'A000180', 'A000300',
#         'A000370', 'A000420', 'A000760', 'A000800',
#         ...
#         'A036460', 'A036580', 'A051630', 'A053210', 'A064350', 'A067250',
#         'A068870', 'A069470', 'A070960', 'A076170'],
#        dtype='object', length=181),
#  Timestamp('2005-03-31 00:00:00'): Index(['A000040', 'A000050', 'A000070', 'A000120', 'A000150', 'A000300',
#         'A000470', 'A000490', 'A000540', 'A000610',
#         ...
#         'A060000', 'A063510', 'A064350', 'A067250', 'A067830', 'A068870',
#         'A070960', 'A074610', 'A076170', 'A079980'],
#        dtype='object', length=240),
#  Timestamp('2005-06-30 00:00:00'): Index(['A000040', 'A000180', 'A000230', 'A000390', 'A000470', 'A000540',
#         'A000760', 'A000910', 'A001070', 'A001140',
#         ...
#         'A032830', 'A034120', 'A034220', 'A035720', 'A042660', 'A047810',
#         'A053210', 'A063510', 'A064350', 'A079660'],
#        dtype='object', length=138),
#  Timestamp('2005-09-30 00:00:00'): Index(['A000110', 'A000180', 'A000420', 'A000680', 'A000760', 'A000830',
#         'A000950', 'A001070', 'A001080', 'A001360',
#         ...
#         'A053210', 'A063510', 'A064350', 'A068870', 'A069470', 'A070960',
#         'A076170', 'A077970', 'A079660', 'A079980'],
#        dtype='object', length=133),
#  Timestamp('2005-12-31 00:00:00'): Index(['A000040', 'A000050', 'A000180', 'A000300', 'A000420', 'A000540',
#         'A000650', 'A000670', 'A000680', 'A000760',
#         ...
#         'A063350', 'A064350', 'A067250', 'A068870', 'A069470', 'A070960',
#         'A071090', 'A076170', 'A079980', 'A084680'],
#        dtype='object', length=178),
#  Timestamp('2006-03-31 00:00:00'): Index(['A000050', 'A000060', 'A000150', 'A000180', 'A000300', 'A000320',
#         'A000370', 'A000400', 'A000420', 'A000490',
#         ...
#         'A064420', 'A067250', 'A069260', 'A069470', 'A071090', 'A076170',
#         'A078520', 'A079660', 'A079980', 'A084680'],
#        dtype='object', length=205),
#  Timestamp('2006-06-30 00:00:00'): Index(['A000040', 'A000150', 'A000180', 'A000300', 'A000370', 'A000390',
#         'A000400', 'A000470', 'A000540', 'A000610',
#         ...
#         'A042660', 'A045820', 'A047810', 'A058430', 'A064960', 'A068870',
#         'A069470', 'A079980', 'A084680', 'A084690'],
#        dtype='object', length=146),
#  Timestamp('2006-09-30 00:00:00'): Index(['A000040', 'A000050', 'A000120', 'A000370', 'A000420', 'A000470',
#         'A000540', 'A000760', 'A000790', 'A000950',
#         ...
#         'A063350', 'A066570', 'A069470', 'A069730', 'A074610', 'A078520',
#         'A079660', 'A079980', 'A084680', 'A085620'],
#        dtype='object', length=150),
#  Timestamp('2006-12-31 00:00:00'): Index(['A000040', 'A000050', 'A000270', 'A000300', 'A000370', 'A000400',
#         'A000420', 'A000490', 'A000540', 'A000650',
#         ...
#         'A049800', 'A063350', 'A070960', 'A073240', 'A074610', 'A076170',
#         'A079980', 'A084680', 'A090080', 'A092220'],
#        dtype='object', length=183),
#  Timestamp('2007-03-31 00:00:00'): Index(['A000040', 'A000050', 'A000070', 'A000080', 'A000110', 'A000150',
#         'A000270', 'A000300', 'A000320', 'A000370',
#         ...
#         'A073240', 'A074610', 'A076170', 'A078520', 'A079660', 'A079980',
#         'A084690', 'A090080', 'A092220', 'A103130'],
#        dtype='object', length=233),
#  Timestamp('2007-06-30 00:00:00'): Index(['A000040', 'A000180', 'A000270', 'A000370', 'A000390', 'A000540',
#         'A000610', 'A000640', 'A000700', 'A000760',
#         ...
#         'A063160', 'A066570', 'A073240', 'A074610', 'A076170', 'A078000',
#         'A081000', 'A089590', 'A090080', 'A092220'],
#        dtype='object', length=146),
#  Timestamp('2007-09-30 00:00:00'): Index(['A000040', 'A000050', 'A000180', 'A000540', 'A000950', 'A000990',
#         'A001040', 'A001070', 'A001190', 'A001380',
#         ...
#         'A049770', 'A063160', 'A069470', 'A070960', 'A074610', 'A076170',
#         'A078520', 'A081000', 'A089590', 'A090080'],
#        dtype='object', length=130),
#  Timestamp('2007-12-31 00:00:00'): Index(['A000050', 'A000180', 'A000270', 'A000320', 'A000420', 'A000490',
#         'A000760', 'A000890', 'A000950', 'A000990',
#         ...
#         'A067830', 'A069470', 'A070960', 'A073240', 'A074610', 'A076170',
#         'A079980', 'A089590', 'A090080', 'A096760'],
#        dtype='object', length=182),
#  Timestamp('2008-03-31 00:00:00'): Index(['A000040', 'A000050', 'A000070', 'A000120', 'A000150', 'A000180',
#         'A000400', 'A000420', 'A000430', 'A000470',
#         ...
#         'A079980', 'A081000', 'A082740', 'A084680', 'A088790', 'A089590',
#         'A090080', 'A096760', 'A097950', 'A133820'],
#        dtype='object', length=211),
#  Timestamp('2008-06-30 00:00:00'): Index(['A000040', 'A000050', 'A000060', 'A000150', 'A000180', 'A000270',
#         'A000320', 'A000400', 'A000420', 'A000470',
#         ...
#         'A074610', 'A076170', 'A079660', 'A079980', 'A082740', 'A085620',
#         'A089590', 'A091090', 'A096760', 'A101530'],
#        dtype='object', length=182),
#  Timestamp('2008-09-30 00:00:00'): Index(['A000050', 'A000180', 'A000300', 'A000420', 'A000470', 'A000660',
#         'A000790', 'A000950', 'A001020', 'A001070',
#         ...
#         'A069460', 'A069470', 'A070960', 'A074610', 'A076170', 'A079980',
#         'A082740', 'A084680', 'A088790', 'A089590'],
#        dtype='object', length=161),
#  Timestamp('2008-12-31 00:00:00'): Index(['A000070', 'A000180', 'A000240', 'A000270', 'A000300', 'A000360',
#         'A000400', 'A000420', 'A000430', 'A000470',
#         ...
#         'A088790', 'A089590', 'A090080', 'A096760', 'A097950', 'A101140',
#         'A101990', 'A102260', 'A103140', 'A103590'],
#        dtype='object', length=278),
#  Timestamp('2009-03-31 00:00:00'): Index(['A000030', 'A000040', 'A000050', 'A000070', 'A000110', 'A000180',
#         'A000210', 'A000220', 'A000240', 'A000320',
#         ...
#         'A097950', 'A100220', 'A101140', 'A101530', 'A101990', 'A102260',
#         'A102280', 'A103140', 'A103590', 'A900030'],
#        dtype='object', length=380),
#  Timestamp('2009-06-30 00:00:00'): Index(['A000040', 'A000050', 'A000060', 'A000180', 'A000220', 'A000320',
#         'A000370', 'A000400', 'A000420', 'A000430',
#         ...
#         'A092220', 'A094280', 'A095570', 'A101060', 'A101140', 'A101990',
#         'A102280', 'A103140', 'A109070', 'A900030'],
#        dtype='object', length=245),
#  Timestamp('2009-09-30 00:00:00'): Index(['A000040', 'A000220', 'A000430', 'A000470', 'A000520', 'A000540',
#         'A000660', 'A000700', 'A000760', 'A000850',
#         ...
#         'A090080', 'A090370', 'A092220', 'A101140', 'A101990', 'A102280',
#         'A104110', 'A109070', 'A900030', 'A900050'],
#        dtype='object', length=153),
#  Timestamp('2009-12-31 00:00:00'): Index(['A000040', 'A000110', 'A000150', 'A000220', 'A000370', 'A000400',
#         'A000470', 'A000680', 'A000700', 'A000760',
#         ...
#         'A084680', 'A084870', 'A088790', 'A089590', 'A092200', 'A093240',
#         'A097230', 'A101140', 'A101990', 'A104110'],
#        dtype='object', length=162),
#  Timestamp('2010-03-31 00:00:00'): Index(['A000040', 'A000050', 'A000120', 'A000140', 'A000470', 'A000490',
#         'A000520', 'A000650', 'A000680', 'A000700',
#         ...
#         'A101990', 'A102260', 'A102280', 'A103150', 'A103590', 'A104110',
#         'A104120', 'A104700', 'A108670', 'A117930'],
#        dtype='object', length=239),
#  Timestamp('2010-06-30 00:00:00'): Index(['A000370', 'A000390', 'A000540', 'A000700', 'A000970', 'A001020',
#         'A001200', 'A001260', 'A001290', 'A001310',
#         ...
#         'A082740', 'A084680', 'A085620', 'A089590', 'A090350', 'A091090',
#         'A101140', 'A101990', 'A102280', 'A117930'],
#        dtype='object', length=123),
#  Timestamp('2010-09-30 00:00:00'): Index(['A000020', 'A000180', 'A000470', 'A000800', 'A000990', 'A001020',
#         'A001200', 'A001260', 'A001310', 'A001440',
#         ...
#         'A093240', 'A101060', 'A101140', 'A101990', 'A102260', 'A105560',
#         'A109070', 'A117580', 'A118000', 'A123690'],
#        dtype='object', length=144),
#  Timestamp('2010-12-31 00:00:00'): Index(['A000020', 'A000140', 'A000180', 'A000220', 'A000400', 'A000420',
#         'A000490', 'A000520', 'A000540', 'A000590',
#         ...
#         'A093240', 'A096760', 'A097230', 'A100840', 'A101990', 'A104700',
#         'A109070', 'A117580', 'A118000', 'A128940'],
#        dtype='object', length=153),
#  Timestamp('2011-03-31 00:00:00'): Index(['A000080', 'A000140', 'A000180', 'A000300', 'A000320', 'A000360',
#         'A000370', 'A000400', 'A000470', 'A000490',
#         ...
#         'A097230', 'A101140', 'A101990', 'A105560', 'A109070', 'A118000',
#         'A123690', 'A128940', 'A130660', 'A950070'],
#        dtype='object', length=220),
#  Timestamp('2011-06-30 00:00:00'): Index(['A000400', 'A000470', 'A000500', 'A000700', 'A000880', 'A000980',
#         'A000990', 'A001140', 'A001260', 'A001290',
#         ...
#         'A100840', 'A101140', 'A101530', 'A101990', 'A109070', 'A114090',
#         'A117930', 'A118000', 'A128820', 'A138040'],
#        dtype='object', length=135),
#  Timestamp('2011-09-30 00:00:00'): Index(['A000300', 'A000320', 'A000470', 'A000500', 'A000520', 'A000700',
#         'A000760', 'A000890', 'A000950', 'A000990',
#         ...
#         'A093240', 'A094280', 'A096760', 'A097230', 'A100840', 'A109070',
#         'A117580', 'A117930', 'A118000', 'A950070'],
#        dtype='object', length=136),
#  Timestamp('2011-12-31 00:00:00'): Index(['A000050', 'A000300', 'A000360', 'A000420', 'A000470', 'A000490',
#         'A000520', 'A000660', 'A000670', 'A000680',
#         ...
#         'A103590', 'A104700', 'A105840', 'A109070', 'A117580', 'A117930',
#         'A118000', 'A128820', 'A128940', 'A900030'],
#        dtype='object', length=254),
#  Timestamp('2012-03-31 00:00:00'): Index(['A000040', 'A000050', 'A000080', 'A000110', 'A000140', 'A000210',
#         'A000300', 'A000320', 'A000360', 'A000420',
#         ...
#         'A117930', 'A118000', 'A119650', 'A123690', 'A128820', 'A128940',
#         'A145990', 'A251270', 'A900030', 'A900050'],
#        dtype='object', length=263),
#  Timestamp('2012-06-30 00:00:00'): Index(['A000040', 'A000050', 'A000220', 'A000300', 'A000360', 'A000470',
#         'A000650', 'A000660', 'A000680', 'A000700',
#         ...
#         'A103590', 'A104120', 'A104700', 'A109070', 'A110570', 'A117930',
#         'A118000', 'A128820', 'A128940', 'A950070'],
#        dtype='object', length=176),
#  Timestamp('2012-09-30 00:00:00'): Index(['A000040', 'A000050', 'A000110', 'A000300', 'A000320', 'A000360',
#         'A000400', 'A000420', 'A000520', 'A000660',
#         ...
#         'A104120', 'A109070', 'A110570', 'A117580', 'A117930', 'A118000',
#         'A123690', 'A128820', 'A130660', 'A950070'],
#        dtype='object', length=192),
#  Timestamp('2012-12-31 00:00:00'): Index(['A000040', 'A000050', 'A000300', 'A000360', 'A000400', 'A000420',
#         'A000490', 'A000520', 'A000680', 'A000700',
#         ...
#         'A110570', 'A117580', 'A117930', 'A118000', 'A123690', 'A123700',
#         'A128820', 'A144620', 'A900050', 'A950070'],
#        dtype='object', length=205),
#  Timestamp('2013-03-31 00:00:00'): Index(['A000020', 'A000040', 'A000070', 'A000140', 'A000300', 'A000320',
#         'A000360', 'A000400', 'A000420', 'A000490',
#         ...
#         'A109070', 'A110570', 'A117930', 'A118000', 'A123690', 'A123700',
#         'A128820', 'A144620', 'A145990', 'A950070'],
#        dtype='object', length=301),
#  Timestamp('2013-06-30 00:00:00'): Index(['A000040', 'A000180', 'A000300', 'A000360', 'A000370', 'A000400',
#         'A000640', 'A000700', 'A000800', 'A000950',
#         ...
#         'A103590', 'A104700', 'A110570', 'A117930', 'A118000', 'A123690',
#         'A128820', 'A138490', 'A170900', 'A950070'],
#        dtype='object', length=223),
#  Timestamp('2013-09-30 00:00:00'): Index(['A000070', 'A000120', 'A000230', 'A000300', 'A000360', 'A000400',
#         'A000420', 'A000490', 'A000520', 'A000540',
#         ...
#         'A110570', 'A117580', 'A117930', 'A118000', 'A119650', 'A123690',
#         'A128820', 'A129260', 'A134790', 'A950070'],
#        dtype='object', length=214),
#  Timestamp('2013-12-31 00:00:00'): Index(['A000020', 'A000040', 'A000110', 'A000120', 'A000150', 'A000180',
#         'A000360', 'A000370', 'A000400', 'A000420',
#         ...
#         'A103590', 'A105840', 'A109070', 'A117580', 'A117930', 'A118000',
#         'A123690', 'A128820', 'A134790', 'A138490'],
#        dtype='object', length=234),
#  Timestamp('2014-03-31 00:00:00'): Index(['A000020', 'A000030', 'A000040', 'A000070', 'A000120', 'A000140',
#         'A000180', 'A000210', 'A000360', 'A000370',
#         ...
#         'A117930', 'A118000', 'A123690', 'A123700', 'A129260', 'A130660',
#         'A134790', 'A138490', 'A144620', 'A950010'],
#        dtype='object', length=317),
#  Timestamp('2014-06-30 00:00:00'): Index(['A000040', 'A000080', 'A000110', 'A000140', 'A000180', 'A000360',
#         'A000400', 'A000420', 'A000520', 'A000700',
#         ...
#         'A109070', 'A110570', 'A117930', 'A118000', 'A119650', 'A123690',
#         'A128820', 'A134790', 'A138490', 'A900050'],
#        dtype='object', length=202),
#  Timestamp('2014-09-30 00:00:00'): Index(['A000040', 'A000220', 'A000360', 'A000400', 'A000420', 'A000520',
#         'A000800', 'A000880', 'A000950', 'A000980',
#         ...
#         'A104110', 'A110570', 'A117580', 'A117930', 'A118000', 'A119650',
#         'A123690', 'A128820', 'A129260', 'A900050'],
#        dtype='object', length=199),
#  Timestamp('2014-12-31 00:00:00'): Index(['A000040', 'A000180', 'A000210', 'A000300', 'A000360', 'A000420',
#         'A000480', 'A000490', 'A000500', 'A000520',
#         ...
#         'A103130', 'A105840', 'A109070', 'A110570', 'A117580', 'A118000',
#         'A120110', 'A128820', 'A144620', 'A900050'],
#        dtype='object', length=226),
#  Timestamp('2015-03-31 00:00:00'): Index(['A000040', 'A000070', 'A000080', 'A000110', 'A000140', 'A000150',
#         'A000180', 'A000210', 'A000300', 'A000360',
#         ...
#         'A123690', 'A128820', 'A129260', 'A130660', 'A134790', 'A139480',
#         'A144620', 'A145990', 'A161000', 'A900050'],
#        dtype='object', length=284),
#  Timestamp('2015-06-30 00:00:00'): Index(['A000040', 'A000150', 'A000180', 'A000220', 'A000640', 'A000760',
#         'A000910', 'A000950', 'A001020', 'A001070',
#         ...
#         'A109070', 'A118000', 'A120110', 'A123690', 'A128820', 'A134790',
#         'A144620', 'A180640', 'A181710', 'A900050'],
#        dtype='object', length=173),
#  Timestamp('2015-09-30 00:00:00'): Index(['A000040', 'A000220', 'A000480', 'A000910', 'A000950', 'A000980',
#         'A001020', 'A001060', 'A001140', 'A001210',
#         ...
#         'A110570', 'A117580', 'A118000', 'A119650', 'A123690', 'A128820',
#         'A130660', 'A145210', 'A180640', 'A185750'],
#        dtype='object', length=166),
#  Timestamp('2015-12-31 00:00:00'): Index(['A000020', 'A000040', 'A000110', 'A000150', 'A000220', 'A000490',
#         'A000680', 'A000950', 'A001020', 'A001070',
#         ...
#         'A118000', 'A119650', 'A123690', 'A128820', 'A128940', 'A134790',
#         'A144620', 'A180640', 'A210540', 'A900050'],
#        dtype='object', length=214),
#  Timestamp('2016-03-31 00:00:00'): Index(['A000040', 'A000110', 'A000150', 'A000240', 'A000300', 'A000400',
#         'A000500', 'A000520', 'A000540', 'A000680',
#         ...
#         'A128820', 'A130660', 'A133820', 'A139480', 'A144620', 'A145210',
#         'A194370', 'A210540', 'A241590', 'A900050'],
#        dtype='object', length=284),
#  Timestamp('2016-06-30 00:00:00'): Index(['A000040', 'A000480', 'A000760', 'A000890', 'A000910', 'A000950',
#         'A000980', 'A001020', 'A001070', 'A001140',
#         ...
#         'A109070', 'A110570', 'A117930', 'A118000', 'A128820', 'A133820',
#         'A134790', 'A180640', 'A183190', 'A900050'],
#        dtype='object', length=155),
#  Timestamp('2016-09-30 00:00:00'): Index(['A000520', 'A000680', 'A000890', 'A000950', 'A000980', 'A001020',
#         'A001060', 'A001070', 'A001210', 'A001310',
#         ...
#         'A117580', 'A117930', 'A118000', 'A119650', 'A128820', 'A129260',
#         'A145210', 'A170900', 'A180640', 'A900050'],
#        dtype='object', length=156),
#  Timestamp('2016-12-31 00:00:00'): Index(['A000040', 'A000300', 'A000400', 'A000490', 'A000680', 'A000700',
#         'A000850', 'A000890', 'A000950', 'A000980',
#         ...
#         'A117580', 'A117930', 'A118000', 'A128820', 'A129260', 'A133820',
#         'A144620', 'A145210', 'A170900', 'A900050'],
#        dtype='object', length=199),
#  Timestamp('2017-03-31 00:00:00'): Index(['A000040', 'A000070', 'A000140', 'A000150', 'A000230', 'A000490',
#         'A000500', 'A000650', 'A000680', 'A000700',
#         ...
#         'A128940', 'A130660', 'A134790', 'A145210', 'A145990', 'A180640',
#         'A181710', 'A213500', 'A227840', 'A900050'],
#        dtype='object', length=249),
#  Timestamp('2017-06-30 00:00:00'): Index(['A000040', 'A000080', 'A000140', 'A000300', 'A000390', 'A000640',
#         'A000700', 'A000910', 'A000950', 'A001020',
#         ...
#         'A109070', 'A111110', 'A118000', 'A123700', 'A128820', 'A144620',
#         'A170900', 'A194370', 'A207940', 'A900050'],
#        dtype='object', length=161),
#  Timestamp('2017-09-30 00:00:00'): Index(['A000040', 'A000230', 'A000300', 'A000520', 'A000760', 'A000950',
#         'A001020', 'A001060', 'A001070', 'A001140',
#         ...
#         'A118000', 'A119650', 'A128820', 'A134790', 'A144620', 'A145210',
#         'A163560', 'A180640', 'A200880', 'A207940'],
#        dtype='object', length=150),
#  Timestamp('2017-12-31 00:00:00'): Index(['A000040', 'A000180', 'A000270', 'A000490', 'A000500', 'A000520',
#         'A000680', 'A000760', 'A000890', 'A000950',
#         ...
#         'A103130', 'A109070', 'A117580', 'A118000', 'A133820', 'A144620',
#         'A145210', 'A204320', 'A207940', 'A214420'],
#        dtype='object', length=160),
#  Timestamp('2018-03-31 00:00:00'): Index(['A000040', 'A000070', 'A000080', 'A000120', 'A000140', 'A000150',
#         'A000180', 'A000210', 'A000320', 'A000480',
#         ...
#         'A207940', 'A210980', 'A213500', 'A214420', 'A248170', 'A267250',
#         'A267260', 'A267270', 'A285130', 'A900140'],
#        dtype='object', length=302),
#  Timestamp('2018-06-30 00:00:00'): Index(['A000040', 'A000180', 'A000390', 'A000520', 'A000540', 'A000640',
#         'A000760', 'A000890', 'A000950', 'A000970',
#         ...
#         'A119650', 'A123700', 'A129260', 'A134790', 'A144620', 'A145210',
#         'A183190', 'A207940', 'A210980', 'A267260'],
#        dtype='object', length=174),
#  Timestamp('2018-09-30 00:00:00'): Index(['A000040', 'A000180', 'A000230', 'A000520', 'A000670', 'A000890',
#         'A000910', 'A000950', 'A001020', 'A001070',
#         ...
#         'A117580', 'A118000', 'A123690', 'A128820', 'A143210', 'A144620',
#         'A180640', 'A207940', 'A214420', 'A900140'],
#        dtype='object', length=172)}

# %%
## Quartarly Change

## invest Date
lag_invest_dates = list(minus_data.keys())[1:]
invest_dates = list(minus_data.keys())[:-1]

ret_data = pd.Series()

for cur_date, lag_date in zip(invest_dates, lag_invest_dates):
    
    ret_data = pd.concat([ret_data, (price_rt.loc[cur_date:lag_date][minus_data[cur_date]]).mean(axis = 1, skipna=True)])

# %%
price_rt['A000280'].loc['2001-06-01':'2001-06-07']
# Out:
# D A T E
# 2001-06-01   -0.473684
# 2001-06-04   -0.300000
# 2001-06-05   -0.142857
# 2001-06-07    0.000000
# Name: A000280, dtype: float64

# %%
ret_data.sub(-1).cumprod().sub(1).plot()

# %%
(ret_data.sub(-1).resample('A').prod().sub(1)).apply(lambda x: '{:.2%}'.format(x))
# Out:
# 2000-12-31     -4.00%
# 2001-12-31     24.63%
# 2002-12-31    -39.01%
# 2003-12-31    -16.01%
# 2004-12-31     -1.54%
# 2005-12-31    114.13%
# 2006-12-31      1.27%
# 2007-12-31     22.77%
# 2008-12-31    -51.33%
# 2009-12-31     42.66%
# 2010-12-31     -7.88%
# 2011-12-31    -13.21%
# 2012-12-31     -8.25%
# 2013-12-31     -3.04%
# 2014-12-31      5.75%
# 2015-12-31     38.57%
# 2016-12-31     -1.39%
# 2017-12-31     -4.69%
# 2018-12-31     15.11%
# Freq: A-DEC, dtype: object

# %%
plus_data = {}
date_index = plus_invest.index

for date in date_index:

    plus_data[date] = (plus_invest.loc[date][plus_invest.loc[date] == True]).index

plus_data
# Out:
# {Timestamp('2000-06-30 00:00:00'): Index(['A000010', 'A000030', 'A000050', 'A000100', 'A000110', 'A000120',
#         'A000140', 'A000150', 'A000210', 'A000240',
#         ...
#         'A034830', 'A035000', 'A035150', 'A035250', 'A035510', 'A035720',
#         'A036460', 'A036530', 'A036570', 'A036580'],
#        dtype='object', length=465),
#  Timestamp('2000-09-30 00:00:00'): Index(['A000020', 'A000100', 'A000110', 'A000120', 'A000140', 'A000150',
#         'A000220', 'A000230', 'A000240', 'A000270',
#         ...
#         'A034220', 'A034300', 'A034830', 'A035000', 'A035250', 'A035720',
#         'A036460', 'A036530', 'A036570', 'A036580'],
#        dtype='object', length=446),
#  Timestamp('2000-12-31 00:00:00'): Index(['A000010', 'A000020', 'A000050', 'A000070', 'A000100', 'A000110',
#         'A000120', 'A000140', 'A000150', 'A000210',
#         ...
#         'A034120', 'A034220', 'A034300', 'A034830', 'A035000', 'A035510',
#         'A036530', 'A036570', 'A036580', 'A039130'],
#        dtype='object', length=422),
#  Timestamp('2001-03-31 00:00:00'): Index(['A000020', 'A000070', 'A000100', 'A000110', 'A000140', 'A000220',
#         'A000230', 'A000240', 'A000270', 'A000320',
#         ...
#         'A035000', 'A035150', 'A035250', 'A036530', 'A036570', 'A042660',
#         'A047040', 'A047050', 'A049770', 'A079980'],
#        dtype='object', length=323),
#  Timestamp('2001-06-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000040', 'A000050', 'A000060',
#         'A000070', 'A000100', 'A000110', 'A000120',
#         ...
#         'A036530', 'A036570', 'A039130', 'A042660', 'A042670', 'A047040',
#         'A049770', 'A051630', 'A051900', 'A051910'],
#        dtype='object', length=484),
#  Timestamp('2001-09-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000060', 'A000100', 'A000110',
#         'A000120', 'A000140', 'A000150', 'A000180',
#         ...
#         'A035510', 'A036530', 'A036580', 'A039130', 'A042660', 'A042670',
#         'A049770', 'A051630', 'A051900', 'A051910'],
#        dtype='object', length=511),
#  Timestamp('2001-12-31 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000050', 'A000060', 'A000070',
#         'A000100', 'A000110', 'A000120', 'A000140',
#         ...
#         'A036580', 'A039130', 'A041650', 'A042660', 'A042670', 'A049770',
#         'A051630', 'A051900', 'A051910', 'A058650'],
#        dtype='object', length=449),
#  Timestamp('2002-03-31 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000060', 'A000070', 'A000100',
#         'A000140', 'A000180', 'A000210', 'A000220',
#         ...
#         'A047050', 'A049770', 'A049800', 'A051630', 'A051900', 'A051910',
#         'A058650', 'A060000', 'A063160', 'A067250'],
#        dtype='object', length=429),
#  Timestamp('2002-06-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000040', 'A000050', 'A000060',
#         'A000070', 'A000100', 'A000110', 'A000120',
#         ...
#         'A058650', 'A058850', 'A058860', 'A060000', 'A063160', 'A064350',
#         'A064420', 'A064960', 'A066570', 'A070960'],
#        dtype='object', length=590),
#  Timestamp('2002-09-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000040', 'A000050', 'A000060',
#         'A000070', 'A000100', 'A000110', 'A000120',
#         ...
#         'A058650', 'A058850', 'A058860', 'A060000', 'A063160', 'A064350',
#         'A064420', 'A064960', 'A066570', 'A067830'],
#        dtype='object', length=547),
#  Timestamp('2002-12-31 00:00:00'): Index(['A000020', 'A000030', 'A000050', 'A000060', 'A000070', 'A000100',
#         'A000110', 'A000120', 'A000140', 'A000150',
#         ...
#         'A058860', 'A060000', 'A063160', 'A064350', 'A066570', 'A067250',
#         'A067830', 'A068290', 'A069260', 'A069730'],
#        dtype='object', length=517),
#  Timestamp('2003-03-31 00:00:00'): Index(['A000020', 'A000060', 'A000070', 'A000080', 'A000100', 'A000110',
#         'A000120', 'A000140', 'A000180', 'A000210',
#         ...
#         'A064350', 'A064420', 'A067250', 'A067830', 'A068290', 'A069260',
#         'A069460', 'A069620', 'A069730', 'A069960'],
#        dtype='object', length=454),
#  Timestamp('2003-06-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000050', 'A000060', 'A000070',
#         'A000100', 'A000120', 'A000140', 'A000150',
#         ...
#         'A067830', 'A068290', 'A069260', 'A069620', 'A069730', 'A069960',
#         'A070960', 'A071090', 'A071840', 'A072130'],
#        dtype='object', length=538),
#  Timestamp('2003-09-30 00:00:00'): Index(['A000020', 'A000030', 'A000050', 'A000060', 'A000070', 'A000100',
#         'A000110', 'A000120', 'A000140', 'A000150',
#         ...
#         'A068870', 'A069260', 'A069460', 'A069620', 'A069730', 'A069960',
#         'A071090', 'A071840', 'A072130', 'A073240'],
#        dtype='object', length=570),
#  Timestamp('2003-12-31 00:00:00'): Index(['A000020', 'A000030', 'A000070', 'A000100', 'A000110', 'A000120',
#         'A000140', 'A000180', 'A000210', 'A000220',
#         ...
#         'A069260', 'A069460', 'A069620', 'A069730', 'A069960', 'A071050',
#         'A071090', 'A071840', 'A072130', 'A072710'],
#        dtype='object', length=515),
#  Timestamp('2004-03-31 00:00:00'): Index(['A000020', 'A000030', 'A000040', 'A000060', 'A000070', 'A000080',
#         'A000100', 'A000110', 'A000120', 'A000140',
#         ...
#         'A068870', 'A069260', 'A069620', 'A069730', 'A071050', 'A071090',
#         'A071840', 'A072130', 'A072710', 'A074610'],
#        dtype='object', length=448),
#  Timestamp('2004-06-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000050', 'A000060', 'A000070',
#         'A000100', 'A000110', 'A000120', 'A000140',
#         ...
#         'A070960', 'A071050', 'A071090', 'A071840', 'A072130', 'A072710',
#         'A074610', 'A076170', 'A077500', 'A078000'],
#        dtype='object', length=585),
#  Timestamp('2004-09-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000060', 'A000070', 'A000080',
#         'A000100', 'A000110', 'A000120', 'A000140',
#         ...
#         'A071090', 'A071840', 'A072130', 'A072710', 'A074610', 'A076170',
#         'A077500', 'A077970', 'A078000', 'A079160'],
#        dtype='object', length=579),
#  Timestamp('2004-12-31 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000060', 'A000070', 'A000100',
#         'A000110', 'A000120', 'A000140', 'A000210',
#         ...
#         'A072710', 'A073240', 'A074610', 'A077500', 'A077970', 'A078000',
#         'A078520', 'A078930', 'A079160', 'A079660'],
#        dtype='object', length=545),
#  Timestamp('2005-03-31 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000060', 'A000080', 'A000100',
#         'A000110', 'A000140', 'A000180', 'A000210',
#         ...
#         'A072710', 'A073240', 'A077500', 'A077970', 'A078000', 'A078520',
#         'A078930', 'A079160', 'A079660', 'A081000'],
#        dtype='object', length=486),
#  Timestamp('2005-06-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000050', 'A000060', 'A000070',
#         'A000080', 'A000100', 'A000110', 'A000120',
#         ...
#         'A076170', 'A077500', 'A077970', 'A078000', 'A078520', 'A078930',
#         'A079160', 'A079980', 'A081000', 'A082740'],
#        dtype='object', length=584),
#  Timestamp('2005-09-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000040', 'A000050', 'A000060',
#         'A000070', 'A000080', 'A000100', 'A000120',
#         ...
#         'A073240', 'A074610', 'A077500', 'A078000', 'A078520', 'A078930',
#         'A079160', 'A081000', 'A082740', 'A084010'],
#        dtype='object', length=585),
#  Timestamp('2005-12-31 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000060', 'A000070', 'A000080',
#         'A000100', 'A000110', 'A000120', 'A000140',
#         ...
#         'A079160', 'A079430', 'A079660', 'A081000', 'A082740', 'A083420',
#         'A084010', 'A084670', 'A084690', 'A086280'],
#        dtype='object', length=544),
#  Timestamp('2006-03-31 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000040', 'A000070', 'A000080',
#         'A000100', 'A000110', 'A000120', 'A000140',
#         ...
#         'A079430', 'A081000', 'A082740', 'A083420', 'A084010', 'A084670',
#         'A084690', 'A085620', 'A086280', 'A086790'],
#        dtype='object', length=519),
#  Timestamp('2006-06-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000050', 'A000060', 'A000070',
#         'A000080', 'A000100', 'A000110', 'A000120',
#         ...
#         'A081000', 'A082740', 'A083420', 'A084010', 'A084670', 'A084870',
#         'A085620', 'A086280', 'A086790', 'A088790'],
#        dtype='object', length=582),
#  Timestamp('2006-09-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000060', 'A000070', 'A000080',
#         'A000100', 'A000110', 'A000140', 'A000150',
#         ...
#         'A084010', 'A084670', 'A084690', 'A084870', 'A086280', 'A086790',
#         'A088790', 'A090080', 'A090350', 'A090430'],
#        dtype='object', length=580),
#  Timestamp('2006-12-31 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000060', 'A000070', 'A000080',
#         'A000100', 'A000110', 'A000120', 'A000140',
#         ...
#         'A084870', 'A085620', 'A086280', 'A086790', 'A088790', 'A089470',
#         'A090350', 'A090430', 'A091090', 'A092230'],
#        dtype='object', length=551),
#  Timestamp('2007-03-31 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000060', 'A000100', 'A000120',
#         'A000140', 'A000180', 'A000210', 'A000220',
#         ...
#         'A086790', 'A088790', 'A089470', 'A090350', 'A090370', 'A090430',
#         'A091090', 'A092230', 'A093050', 'A093370'],
#        dtype='object', length=503),
#  Timestamp('2007-06-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000050', 'A000060', 'A000070',
#         'A000080', 'A000100', 'A000110', 'A000120',
#         ...
#         'A089470', 'A090350', 'A090370', 'A090430', 'A091090', 'A092230',
#         'A093050', 'A093370', 'A094280', 'A095570'],
#        dtype='object', length=588),
#  Timestamp('2007-09-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000060', 'A000070', 'A000080',
#         'A000100', 'A000110', 'A000120', 'A000140',
#         ...
#         'A090430', 'A091090', 'A092220', 'A092230', 'A092440', 'A093050',
#         'A093370', 'A094280', 'A095570', 'A095720'],
#        dtype='object', length=604),
#  Timestamp('2007-12-31 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000040', 'A000060', 'A000070',
#         'A000080', 'A000100', 'A000110', 'A000120',
#         ...
#         'A092440', 'A093050', 'A093230', 'A093370', 'A094280', 'A095570',
#         'A095720', 'A096770', 'A097230', 'A097950'],
#        dtype='object', length=561),
#  Timestamp('2008-03-31 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000060', 'A000080', 'A000100',
#         'A000110', 'A000140', 'A000210', 'A000220',
#         ...
#         'A092230', 'A092440', 'A093050', 'A093230', 'A093370', 'A094280',
#         'A095570', 'A095720', 'A096770', 'A097230'],
#        dtype='object', length=534),
#  Timestamp('2008-06-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000070', 'A000080', 'A000100',
#         'A000110', 'A000120', 'A000140', 'A000210',
#         ...
#         'A095570', 'A095720', 'A096770', 'A097230', 'A097950', 'A100220',
#         'A100250', 'A100840', 'A101060', 'A101140'],
#        dtype='object', length=568),
#  Timestamp('2008-09-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000040', 'A000060', 'A000070',
#         'A000080', 'A000100', 'A000110', 'A000120',
#         ...
#         'A097950', 'A100220', 'A100250', 'A100840', 'A101060', 'A101140',
#         'A101530', 'A101990', 'A102260', 'A102280'],
#        dtype='object', length=592),
#  Timestamp('2008-12-31 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000040', 'A000050', 'A000060',
#         'A000080', 'A000100', 'A000110', 'A000120',
#         ...
#         'A101530', 'A102280', 'A103150', 'A103160', 'A104110', 'A104120',
#         'A104700', 'A105560', 'A144620', 'A900030'],
#        dtype='object', length=485),
#  Timestamp('2009-03-31 00:00:00'): Index(['A000010', 'A000020', 'A000060', 'A000080', 'A000100', 'A000120',
#         'A000140', 'A000150', 'A000230', 'A000270',
#         ...
#         'A100840', 'A101060', 'A103150', 'A103160', 'A104110', 'A104120',
#         'A104700', 'A105560', 'A144620', 'A900140'],
#        dtype='object', length=383),
#  Timestamp('2009-06-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000070', 'A000080', 'A000100',
#         'A000110', 'A000120', 'A000140', 'A000150',
#         ...
#         'A103150', 'A103590', 'A104110', 'A104120', 'A104700', 'A105560',
#         'A105630', 'A107590', 'A108070', 'A900050'],
#        dtype='object', length=516),
#  Timestamp('2009-09-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000050', 'A000060', 'A000070',
#         'A000080', 'A000100', 'A000110', 'A000120',
#         ...
#         'A103140', 'A103150', 'A103590', 'A104120', 'A104700', 'A105560',
#         'A105630', 'A107590', 'A108070', 'A108670'],
#        dtype='object', length=603),
#  Timestamp('2009-12-31 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000050', 'A000060', 'A000070',
#         'A000080', 'A000100', 'A000120', 'A000140',
#         ...
#         'A105630', 'A105840', 'A107590', 'A108070', 'A108670', 'A109070',
#         'A111770', 'A114410', 'A900030', 'A900050'],
#        dtype='object', length=604),
#  Timestamp('2010-03-31 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000060', 'A000070', 'A000080',
#         'A000100', 'A000110', 'A000150', 'A000180',
#         ...
#         'A105840', 'A107590', 'A108070', 'A109070', 'A111770', 'A114410',
#         'A117580', 'A118000', 'A900030', 'A900050'],
#        dtype='object', length=527),
#  Timestamp('2010-06-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000040', 'A000050', 'A000060',
#         'A000070', 'A000080', 'A000100', 'A000110',
#         ...
#         'A114090', 'A114410', 'A115390', 'A117580', 'A118000', 'A119650',
#         'A120030', 'A120110', 'A900030', 'A900050'],
#        dtype='object', length=636),
#  Timestamp('2010-09-30 00:00:00'): Index(['A000010', 'A000030', 'A000040', 'A000050', 'A000060', 'A000070',
#         'A000080', 'A000100', 'A000110', 'A000120',
#         ...
#         'A115390', 'A117930', 'A119650', 'A120030', 'A120110', 'A122900',
#         'A123700', 'A128820', 'A900030', 'A900050'],
#        dtype='object', length=617),
#  Timestamp('2010-12-31 00:00:00'): Index(['A000010', 'A000030', 'A000040', 'A000050', 'A000060', 'A000070',
#         'A000080', 'A000100', 'A000110', 'A000120',
#         ...
#         'A120110', 'A122900', 'A123690', 'A123700', 'A126560', 'A128820',
#         'A130660', 'A900030', 'A900050', 'A950070'],
#        dtype='object', length=613),
#  Timestamp('2011-03-31 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000040', 'A000050', 'A000060',
#         'A000070', 'A000100', 'A000110', 'A000120',
#         ...
#         'A119650', 'A120030', 'A120110', 'A122900', 'A123700', 'A126560',
#         'A128820', 'A134790', 'A900030', 'A900050'],
#        dtype='object', length=544),
#  Timestamp('2011-06-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000040', 'A000050', 'A000060',
#         'A000070', 'A000080', 'A000100', 'A000110',
#         ...
#         'A128940', 'A130660', 'A134380', 'A134790', 'A136490', 'A138490',
#         'A138930', 'A900030', 'A900050', 'A900140'],
#        dtype='object', length=633),
#  Timestamp('2011-09-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000040', 'A000050', 'A000060',
#         'A000070', 'A000080', 'A000100', 'A000110',
#         ...
#         'A134790', 'A136490', 'A138040', 'A138490', 'A138930', 'A139130',
#         'A139480', 'A900030', 'A900050', 'A900140'],
#        dtype='object', length=635),
#  Timestamp('2011-12-31 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000040', 'A000060', 'A000070',
#         'A000080', 'A000100', 'A000110', 'A000120',
#         ...
#         'A134380', 'A134790', 'A136490', 'A138040', 'A138490', 'A138930',
#         'A139130', 'A139480', 'A900050', 'A900140'],
#        dtype='object', length=517),
#  Timestamp('2012-03-31 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000060', 'A000070', 'A000100',
#         'A000120', 'A000150', 'A000180', 'A000220',
#         ...
#         'A134380', 'A134790', 'A136490', 'A138040', 'A138490', 'A138930',
#         'A139130', 'A139480', 'A900140', 'A950100'],
#        dtype='object', length=509),
#  Timestamp('2012-06-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000060', 'A000070', 'A000080',
#         'A000100', 'A000110', 'A000120', 'A000140',
#         ...
#         'A138490', 'A138930', 'A139130', 'A139480', 'A144620', 'A145990',
#         'A900030', 'A900050', 'A900140', 'A950100'],
#        dtype='object', length=602),
#  Timestamp('2012-09-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000060', 'A000070', 'A000080',
#         'A000100', 'A000120', 'A000140', 'A000150',
#         ...
#         'A138040', 'A138490', 'A138930', 'A139130', 'A139480', 'A144620',
#         'A145990', 'A900050', 'A900140', 'A950100'],
#        dtype='object', length=577),
#  Timestamp('2012-12-31 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000060', 'A000070', 'A000080',
#         'A000100', 'A000110', 'A000120', 'A000140',
#         ...
#         'A138040', 'A138490', 'A138930', 'A139130', 'A139480', 'A145990',
#         'A161000', 'A161390', 'A900140', 'A950100'],
#        dtype='object', length=565),
#  Timestamp('2013-03-31 00:00:00'): Index(['A000010', 'A000030', 'A000050', 'A000060', 'A000080', 'A000100',
#         'A000110', 'A000120', 'A000150', 'A000180',
#         ...
#         'A138930', 'A139130', 'A139480', 'A161000', 'A161390', 'A161890',
#         'A163560', 'A900050', 'A900140', 'A950100'],
#        dtype='object', length=463),
#  Timestamp('2013-06-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000050', 'A000060', 'A000070',
#         'A000080', 'A000100', 'A000110', 'A000120',
#         ...
#         'A139480', 'A144620', 'A145990', 'A161000', 'A161390', 'A161890',
#         'A163560', 'A900050', 'A900140', 'A950100'],
#        dtype='object', length=541),
#  Timestamp('2013-09-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000040', 'A000050', 'A000060',
#         'A000080', 'A000100', 'A000110', 'A000140',
#         ...
#         'A145990', 'A155660', 'A161000', 'A161390', 'A161890', 'A163560',
#         'A170900', 'A900050', 'A900140', 'A950100'],
#        dtype='object', length=552),
#  Timestamp('2013-12-31 00:00:00'): Index(['A000010', 'A000030', 'A000050', 'A000060', 'A000070', 'A000080',
#         'A000100', 'A000140', 'A000210', 'A000220',
#         ...
#         'A161390', 'A161890', 'A163560', 'A170900', 'A175330', 'A180640',
#         'A181710', 'A900050', 'A900140', 'A950100'],
#        dtype='object', length=533),
#  Timestamp('2014-03-31 00:00:00'): Index(['A000010', 'A000050', 'A000060', 'A000080', 'A000100', 'A000110',
#         'A000150', 'A000220', 'A000230', 'A000240',
#         ...
#         'A163560', 'A170900', 'A175330', 'A180640', 'A181710', 'A183190',
#         'A185750', 'A900050', 'A900140', 'A950100'],
#        dtype='object', length=452),
#  Timestamp('2014-06-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000050', 'A000060', 'A000070',
#         'A000100', 'A000120', 'A000150', 'A000210',
#         ...
#         'A170900', 'A175330', 'A180640', 'A181710', 'A183190', 'A185750',
#         'A192400', 'A192820', 'A900140', 'A950100'],
#        dtype='object', length=568),
#  Timestamp('2014-09-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000050', 'A000060', 'A000070',
#         'A000080', 'A000100', 'A000110', 'A000120',
#         ...
#         'A175330', 'A180640', 'A181710', 'A183190', 'A185750', 'A192520',
#         'A192530', 'A192820', 'A900140', 'A950100'],
#        dtype='object', length=570),
#  Timestamp('2014-12-31 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000050', 'A000060', 'A000070',
#         'A000080', 'A000100', 'A000110', 'A000120',
#         ...
#         'A183190', 'A185750', 'A192400', 'A192520', 'A192530', 'A192820',
#         'A200880', 'A204320', 'A900140', 'A950100'],
#        dtype='object', length=546),
#  Timestamp('2015-03-31 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000050', 'A000060', 'A000100',
#         'A000120', 'A000220', 'A000230', 'A000240',
#         ...
#         'A185750', 'A192400', 'A192520', 'A192530', 'A192820', 'A200880',
#         'A204320', 'A210540', 'A272550', 'A900140'],
#        dtype='object', length=485),
#  Timestamp('2015-06-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000050', 'A000060', 'A000070',
#         'A000080', 'A000100', 'A000110', 'A000120',
#         ...
#         'A192820', 'A200880', 'A204320', 'A210540', 'A210980', 'A213500',
#         'A214320', 'A214390', 'A214420', 'A900140'],
#        dtype='object', length=598),
#  Timestamp('2015-09-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000050', 'A000060', 'A000070',
#         'A000080', 'A000100', 'A000110', 'A000120',
#         ...
#         'A192530', 'A192820', 'A200880', 'A204320', 'A210540', 'A210980',
#         'A213500', 'A214390', 'A900050', 'A900140'],
#        dtype='object', length=601),
#  Timestamp('2015-12-31 00:00:00'): Index(['A000010', 'A000030', 'A000050', 'A000060', 'A000070', 'A000080',
#         'A000100', 'A000120', 'A000140', 'A000180',
#         ...
#         'A194370', 'A200880', 'A204320', 'A210980', 'A213500', 'A214320',
#         'A214390', 'A214420', 'A226320', 'A900140'],
#        dtype='object', length=558),
#  Timestamp('2016-03-31 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000050', 'A000060', 'A000070',
#         'A000080', 'A000100', 'A000120', 'A000140',
#         ...
#         'A200880', 'A204320', 'A210980', 'A213500', 'A214320', 'A214390',
#         'A214420', 'A226320', 'A227840', 'A900140'],
#        dtype='object', length=489),
#  Timestamp('2016-06-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000050', 'A000060', 'A000070',
#         'A000080', 'A000100', 'A000110', 'A000120',
#         ...
#         'A210540', 'A210980', 'A213500', 'A214320', 'A214330', 'A214390',
#         'A214420', 'A226320', 'A227840', 'A900140'],
#        dtype='object', length=621),
#  Timestamp('2016-09-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000040', 'A000050', 'A000060',
#         'A000070', 'A000080', 'A000100', 'A000110',
#         ...
#         'A214320', 'A214330', 'A214390', 'A214420', 'A226320', 'A227840',
#         'A234080', 'A241560', 'A241590', 'A900140'],
#        dtype='object', length=622),
#  Timestamp('2016-12-31 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000050', 'A000060', 'A000070',
#         'A000080', 'A000100', 'A000110', 'A000120',
#         ...
#         'A214420', 'A226320', 'A227840', 'A229640', 'A234080', 'A241560',
#         'A241590', 'A248170', 'A249420', 'A900140'],
#        dtype='object', length=580),
#  Timestamp('2017-03-31 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000050', 'A000060', 'A000080',
#         'A000100', 'A000110', 'A000120', 'A000180',
#         ...
#         'A214330', 'A214390', 'A214420', 'A226320', 'A229640', 'A234080',
#         'A241590', 'A248170', 'A249420', 'A900140'],
#        dtype='object', length=525),
#  Timestamp('2017-06-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000050', 'A000060', 'A000070',
#         'A000100', 'A000110', 'A000120', 'A000150',
#         ...
#         'A226320', 'A227840', 'A229640', 'A234080', 'A241560', 'A241590',
#         'A248170', 'A249420', 'A264900', 'A900140'],
#        dtype='object', length=615),
#  Timestamp('2017-09-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000050', 'A000060', 'A000070',
#         'A000080', 'A000100', 'A000110', 'A000120',
#         ...
#         'A251270', 'A264900', 'A267250', 'A267260', 'A267270', 'A267290',
#         'A268280', 'A271560', 'A271980', 'A900140'],
#        dtype='object', length=631),
#  Timestamp('2017-12-31 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000050', 'A000060', 'A000070',
#         'A000080', 'A000100', 'A000110', 'A000120',
#         ...
#         'A251270', 'A264900', 'A267250', 'A267260', 'A267270', 'A267290',
#         'A268280', 'A271560', 'A271980', 'A900140'],
#        dtype='object', length=619),
#  Timestamp('2018-03-31 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000050', 'A000060', 'A000100',
#         'A000110', 'A000220', 'A000230', 'A000240',
#         ...
#         'A267290', 'A268280', 'A271560', 'A271980', 'A280360', 'A281820',
#         'A282330', 'A282690', 'A284740', 'A286940'],
#        dtype='object', length=485),
#  Timestamp('2018-06-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000050', 'A000060', 'A000070',
#         'A000080', 'A000100', 'A000110', 'A000120',
#         ...
#         'A272450', 'A272550', 'A280360', 'A281820', 'A282330', 'A282690',
#         'A284740', 'A285130', 'A286940', 'A900140'],
#        dtype='object', length=616),
#  Timestamp('2018-09-30 00:00:00'): Index(['A000010', 'A000020', 'A000030', 'A000050', 'A000060', 'A000070',
#         'A000080', 'A000100', 'A000110', 'A000120',
#         ...
#         'A281820', 'A282330', 'A282690', 'A284740', 'A285130', 'A294870',
#         'A298000', 'A298020', 'A298040', 'A298050'],
#        dtype='object', length=621)}

# %%
## Quartarly Change

## invest Date
lag_invest_dates = list(plus_data.keys())[1:]
invest_dates = list(plus_data.keys())[:-1]

plus_ret_data = pd.Series()

for cur_date, lag_date in zip(invest_dates, lag_invest_dates):
    
    plus_ret_data = pd.concat([plus_ret_data, (price_rt.loc[cur_date:lag_date][plus_data[cur_date]]).mean(axis = 1)])

# %%
plus_ret_data.sub(-1).cumprod().sub(1).plot()

# %%
(plus_ret_data.sub(-1).resample('A').prod().sub(1)).apply(lambda x: '{:.2%}'.format(x))
# Out:
# 2000-12-31    -18.68%
# 2001-12-31     67.01%
# 2002-12-31     -6.26%
# 2003-12-31     19.32%
# 2004-12-31     20.80%
# 2005-12-31    118.13%
# 2006-12-31     13.34%
# 2007-12-31     48.38%
# 2008-12-31    -37.76%
# 2009-12-31     61.30%
# 2010-12-31     24.39%
# 2011-12-31      0.76%
# 2012-12-31     13.54%
# 2013-12-31     13.18%
# 2014-12-31     18.52%
# 2015-12-31     26.28%
# 2016-12-31      1.87%
# 2017-12-31      7.28%
# 2018-12-31      6.59%
# Freq: A-DEC, dtype: object
