# %%
from FileOpener.CSVReader.CSVReader import CSVReader

# %% [markdown]
# ## EPS Loading

# %%
eps_dir = "CSVFile/FinancialData/Korea"
eps_file = "EPS_KSE.csv"

eps_kse = CSVReader.financial_reader(filename=eps_file, directory=eps_dir)

# %%
eps_kse.head()
# Out:
#             A000010  A000020  A000030  A000040  A000050  A000060  A000070  \
# Code
# 2000-12-31    149.0    147.0  -3445.0 -83946.0    106.0   -199.0   2483.0
# 2001-12-31    769.0    248.0   1290.0 -31812.0    -14.0    440.0    640.0
# 2002-12-31   -863.0    311.0   1410.0  98503.0    145.0    343.0   2970.0
# 2003-12-31  -1421.0    213.0   2377.0    565.0      7.0    202.0   3665.0
# 2004-12-31    369.0    266.0   3221.0   -365.0   -345.0    213.0   5095.0
#
#                A000080  A000090  A000100  ...  A298050  A298690  A300720  \
# Code                                      ...
# 2000-12-31   2105884.0      NaN   2922.0  ...      NaN      NaN      NaN
# 2001-12-31  -2950982.0      NaN   3454.0  ...      NaN      NaN      NaN
# 2002-12-31  -3875275.0      NaN   3789.0  ...      NaN      NaN      NaN
# 2003-12-31 -23280086.0      NaN   4412.0  ...      NaN      NaN      NaN
# 2004-12-31    474316.0      NaN   4317.0  ...      NaN      NaN      NaN
#
# ...

# %% [markdown]
# ## Price Loading

# %%
prc_dir = "CSVFile/Price/Korea/"
prc_file = "KOSPI_FROM_1998_close.csv"

prc_kse = CSVReader.price_reader(filename=prc_file, directory=prc_dir)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-64f084859d9c> in <module>
#       2 prc_file = "KOSPI_FROM_1998_close.csv"
#       3
# ----> 4 prc_kse = CSVReader.price_reader(filename=prc_file, directory=prc_dir)
#
# D:\Project\팩터분석\WiseData\FileOpener\CSVReader\CSVReader.py in price_reader(filename, directory)
#      29     def price_reader(filename, directory):
#      30
# ---> 31         return pd.read_csv(f"{directory}/{filename}", index_col = 'D A T E', parse_dates=True)
#      32
#
# ...
