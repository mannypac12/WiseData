# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from FileOpener.CSVReader.CSVReader import CSVReader as csv
from pf_anlysis import PfAnalysis as pf

# %%
price_dir = 'CSVFile/Price/Korea/Stocks'
opincome_dir = 'CSVFile/FinancialData/Korea'


kdq_price = csv.price_reader(filename='KOSDAQ_FROM_1998_close.csv', directory=price_dir)
kse_price = csv.price_reader(filename='KOSPI_FROM_1998_close.csv', directory=price_dir)

kdq_op_income = csv.financial_reader(filename='OP_INCOME_KDQ.csv', directory=opincome_dir)
kse_op_income = csv.financial_reader(filename='OP_INCOME_KSE.csv', directory=opincome_dir)

# %% [markdown]
# # KOSPI

# %%
kse_op_ic_yoy = kse_op_income.shift(1).pct_change(periods=4).dropna(axis=0, how='all') > 0.25

# %%
kse_idices = kse_op_ic_yoy.index

kse_stocks = {}

for idx in kse_idices:
    
    kse_stocks[idx] = (kse_op_ic_yoy.loc[idx][kse_op_ic_yoy.loc[idx] == True]).index

# %%
kse_price_rt = kse_price.pct_change().loc['2001-06-30':'2018-09-30']

# %%
b, c, d = a.back_date(kse_op_ic_yoy,  freq='Q')
stock = a.stock_screen(kse_op_ic_yoy)

kse_ret_data = pd.Series()

for n_start, start, end in zip(b,c,d):
    
    kse_ret_data = pd.concat([kse_ret_data, kse_price_rt[stock[n_start]].loc[start:end].mean(axis=1)])

# %%
kse_ret_data
# Out:
# 2001-07-02    0.002658
# 2001-07-03   -0.003311
# 2001-07-04   -0.001469
# 2001-07-05   -0.002067
# 2001-07-06   -0.012726
# 2001-07-09   -0.043014
# 2001-07-10    0.009856
# 2001-07-11   -0.019093
# 2001-07-12    0.020403
# 2001-07-13   -0.018459
# 2001-07-16    0.000976
# 2001-07-18   -0.019311
# 2001-07-19   -0.006814
# 2001-07-20   -0.006798
# 2001-07-23   -0.042434
# 2001-07-24    0.000317
# 2001-07-25    0.002298
# 2001-07-26    0.014920
# 2001-07-27    0.023117
# 2001-07-30   -0.007837
# 2001-07-31    0.021022
# 2001-08-01    0.020458
# 2001-08-02    0.004146
# 2001-08-03    0.000380
# 2001-08-06    0.007005
# 2001-08-07    0.003179
# 2001-08-08    0.001136
# 2001-08-09   -0.006638
# 2001-08-10    0.010272
# 2001-08-13    0.013144
#                 ...
# 2018-08-14    0.013569
# 2018-08-16   -0.000412
# 2018-08-17    0.007520
# 2018-08-20    0.002076
# 2018-08-21    0.009282
# 2018-08-22   -0.001256
# 2018-08-23    0.001886
# 2018-08-24    0.004437
# 2018-08-27   -0.005676
# 2018-08-28    0.001639
# 2018-08-29    0.002157
# 2018-08-30    0.000397
# 2018-08-31    0.004024
# 2018-09-03   -0.001319
# 2018-09-04    0.007061
# 2018-09-05   -0.000155
# 2018-09-06   -0.003439
# 2018-09-07    0.004798
# 2018-09-10    0.009139
# 2018-09-11    0.006762
# 2018-09-12   -0.000819
# 2018-09-13    0.005060
# 2018-09-14    0.006223
# 2018-09-17   -0.007290
# 2018-09-18   -0.003684
# 2018-09-19   -0.010828
# 2018-09-20   -0.007266
# 2018-09-21    0.008366
# 2018-09-27    0.004682
# 2018-09-28   -0.001601
# Length: 4265, dtype: float64

# %%
kse_norm_dates = kse_op_ic_yoy.index
kse_n_starts = kse_norm_dates[:-1]
kse_starts = kse_n_starts + pd.tseries.offsets.MonthBegin()
kse_ends = kse_norm_dates[1:]

# %%
kse_ret_data = pd.Series()

for n_start, start, end in zip(kse_n_starts, kse_starts, kse_ends):
    
    kse_ret_data = pd.concat([kse_ret_data, kse_price_rt[kse_stocks[n_start]].loc[start:end].mean(axis=1)])

# %%
kse_op_25_ret = pf(kse_ret_data)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)

ax.set_title('KSE Operating Income MORE THAN 25%')
kse_op_25_ret.cumReturn().plot(ax = ax)

# %%
# 1년
max_drawdown = kse_op_25_ret.maxDrawDown(windows=252)
print(f"Maximum Drawdown for the strategy is {abs(round(max_drawdown*100, 2))}%")
print(f"Total Return on the strategyis {abs(round((kse_op_25_ret.data.prod() * 100),2))}%")
# Out:
# Maximum Drawdown for the strategy is 57.31%
# Total Return on the strategyis 3114.52%

# %%
(kse_op_25_ret.data.resample('A').prod().sub(1)).apply(lambda x: "{:,.2%}".format(x))
# Out:
# 2001-12-31     10.98%
# 2002-12-31     -3.45%
# 2003-12-31     32.27%
# 2004-12-31     26.82%
# 2005-12-31    134.42%
# 2006-12-31      7.54%
# 2007-12-31     69.06%
# 2008-12-31    -36.62%
# 2009-12-31     67.35%
# 2010-12-31     31.99%
# 2011-12-31     -0.69%
# 2012-12-31     20.80%
# 2013-12-31     16.81%
# 2014-12-31     33.85%
# 2015-12-31     34.90%
# 2016-12-31      0.53%
# 2017-12-31      6.14%
# 2018-12-31      7.56%
# Freq: A-DEC, dtype: object

# %% [markdown]
# # KOSDAQ

# %% [markdown]
# ## 재무 데이터 유니버스 선정
#
# 영업이익 전년대비 25% 상승 이상

# %%
kdq_op_ic_yoy = kdq_op_income.shift(1).pct_change(periods=4).dropna(axis=0, how='all') > 0.25

# %%
kdq_op_ic_yoy.head()
# Out:
#             A000250  A000440  A001000  A001540  A001810  A001840  A002230  \
# Code
# 2001-06-30    False    False    False    False    False     True    False
# 2001-09-30    False    False    False    False    False     True    False
# 2001-12-31    False    False    False    False     True    False    False
# 2002-03-31    False    False    False     True    False     True     True
# 2002-06-30    False     True    False     True     True     True    False
#
#             A002290  A002680  A002800   ...     A900280  A900290  A900300  \
# Code                                    ...
# 2001-06-30     True    False    False   ...       False    False    False
# 2001-09-30    False    False    False   ...       False    False    False
# 2001-12-31    False     True    False   ...       False    False    False
# 2002-03-31    False     True    False   ...       False    False    False
# 2002-06-30    False     True    False   ...       False    False    False
#
#             A900310  A900340  A950110  A950130  A950140  A950160  A950170
# Code
# 2001-06-30    False    False    False    False    False    False    False
# 2001-09-30    False    False    False    False    False    False    False
# 2001-12-31    False    False    False    False    False    False    False
# 2002-03-31    False    False    False    False    False    False    False
# 2002-06-30    False    False    False    False    False    False    False
#
# [5 rows x 1278 columns]

# %%
## 25% 이상 주식의 수

kdq_op_ic_yoy.sum(axis = 1).head()
# Out:
# Code
# 2001-06-30     51
# 2001-09-30     64
# 2001-12-31     83
# 2002-03-31     79
# 2002-06-30    106
# dtype: int64

# %%
kdq_op_ic_yoy.sum(axis = 1).tail()
# Out:
# Code
# 2017-09-30    342
# 2017-12-31    365
# 2018-03-31    292
# 2018-06-30    362
# 2018-09-30    364
# dtype: int64

# %%
idices = kdq_op_ic_yoy.index

stocks = {}

for idx in idices:
    
    stocks[idx] = (kdq_op_ic_yoy.loc[idx][kdq_op_ic_yoy.loc[idx] == True]).index

# %% [markdown]
# ## 수익률

# %%
price_rt = kdq_price.pct_change().loc['2001-06-30':'2018-09-30']

# %% [markdown]
# ## 백테스트

# %%
norm_dates = kdq_op_ic_yoy.index
n_starts = norm_dates[:-1]
starts = n_starts + pd.tseries.offsets.MonthBegin()
ends = norm_dates[1:]

# %%
ret_data = pd.Series()

for n_start, start, end in zip(list(n_starts), list(starts), list(ends)):
    
    ret_data = pd.concat([ret_data, price_rt[stocks[n_start]].loc[start:end].mean(axis=1)])

# %% [markdown]
# ## Performance Analytics

# %%
kdq_op_25_ret = pf(ret_data)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)

ax.set_title('KDQ Operating Income MORE THAN 25%')
kdq_op_25_ret.cumReturn().plot(ax = ax)

# %%
# 1년
max_drawdown = kdq_op_25_ret.maxDrawDown(windows=252)
print(f"Maximum Drawdown for the strategy is {abs(round(max_drawdown*100, 2))}%")
print(f"Total Return on the strategyis {abs(round((kdq_op_25_ret.data.prod() * 100),2))}%")
# Out:
# Maximum Drawdown for the strategy is 58.72%
# Total Return on the strategyis 2278.26%

# %%
(kdq_op_25_ret.data.resample('A').prod().sub(1)).apply(lambda x: "{:,.2%}".format(x))
# Out:
# 2001-12-31    -15.56%
# 2002-12-31    -20.40%
# 2003-12-31     14.72%
# 2004-12-31      6.24%
# 2005-12-31    163.60%
# 2006-12-31     11.19%
# 2007-12-31     35.99%
# 2008-12-31    -39.78%
# 2009-12-31    104.03%
# 2010-12-31     22.94%
# 2011-12-31     20.93%
# 2012-12-31     27.07%
# 2013-12-31     14.66%
# 2014-12-31     22.50%
# 2015-12-31     57.73%
# 2016-12-31     17.45%
# 2017-12-31      8.20%
# 2018-12-31      6.76%
# Freq: A-DEC, dtype: object
